# %%
# %matplotlib inline
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import datetime 
from sklearn.metrics.pairwise import cosine_similarity
krfont = {'family' : 'nanumgothic', 'weight' : 'bold', 'size'   : 10}
matplotlib.rc('font', **krfont)
plt.style.use('ggplot')
# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
#matplotlib.rcParams['axes.unicode_minus'] = Falseparse_dates=['date']

# %% [markdown]
# ### 주간 데이터 읽어오기

# %%
df_1 = pd.read_csv('철광석 주간평균(lag).csv',
                encoding='euc-kr',skiprows=6,parse_dates=['Unnamed: 0'])
df_2 = pd.read_csv('철광석 주간평균(lag)2.csv',
                encoding='euc-kr',skiprows=6,parse_dates=['Unnamed: 0'])
df_3 = pd.read_csv('철광석 주간평균(lag)3.csv',
                encoding='euc-kr',skiprows=6,parse_dates=['Unnamed: 0'])

# %%
df1 = pd.merge(df_1,df_2,on=['Unnamed: 0', '철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton'])
df = pd.merge(df1,df_3,on=['Unnamed: 0', '철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton'])

# %%
df.head()
# Out:
#   Unnamed: 0  철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton  중국 철광석 생산량10000 tons  \
# 0 2018-07-09                                      63.92                6746.8
# 1 2018-07-02                                      64.05                6746.8
# 2 2018-06-25                                      65.23                6746.8
# 3 2018-06-18                                      66.13                6746.8
# 4 2018-06-11                                      67.37                6746.8
#
#    주요 중국 철광석 항구재고량mmt  Bloomberg(DJ-UBS) Commodity Index1991=100  \
# 0              153.42                                      86.13
# 1              153.42                                      85.85
# 2              155.79                                      86.81
# 3              154.90                                      86.95
# 4              157.23                                      89.29
#
#    Bloomberg Commodity Total Return1991=100  TR/CC CRB Index1967=100  \
# 0                                    177.41                   198.23
# 1                                    176.79                   197.31
# 2                                    178.70                   198.16
# 3                                    178.91                   195.38
# 4                                    183.66                   198.97
#
#    S&P GSCI1970=100  GSCI Energy1970=100  GSCI Petroleum1970=100  \
# 0            481.11               245.63                  269.96
# 1            479.98               244.80                  268.86
# 2            477.91               241.55                  264.78
# 3            465.20               228.23                  249.45
# 4            473.52               231.60                  253.27
#
#                                 ...                                \
# 0                               ...
# 1                               ...
# 2                               ...
# 3                               ...
# 4                               ...
#
#    SSY/Pacific Capesize Index1997.1.6=4114  \
# 0                                   6034.0
# 1                                   4997.0
# 2                                   4977.0
# 3                                   5455.0
# 4                                   5372.0
#
#    SSY/Atlantic Capesize Index1997.1.6=5000  \
# 0                                    9953.0
# 1                                    8625.0
# 2                                    8038.0
# 3                                    8331.0
# 4                                    7908.0
#
#    Howe Robinson Container Index1997.1.15=1000  \
# 0                                        832.0
# 1                                        832.0
# 2                                        842.0
# 3                                        843.0
# 4                                        846.0
#
#    China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 0                                             808.55
# 1                                             808.55
# 2                                             815.89
# 3                                             812.18
# 4                                             814.83
#
#    Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 0                                             817.40
# 1                                             817.40
# 2                                             821.18
# 3                                             751.13
# 4                                             777.70
#
#    China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 0                                            1088.39
# 1                                            1088.39
# 2                                            1105.50
# 3                                            1133.57
# 4                                            1150.02
#
#    China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 0                                              801.0
# 1                                              801.0
# 2                                              801.0
# 3                                              794.0
# 4                                              794.0
#
#    China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 0                                              828.0
# 1                                              828.0
# 2                                              828.0
# 3                                              824.0
# 4                                              824.0
#
#    China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 0                                              855.0
# 1                                              855.0
# 2                                              855.0
# 3                                              849.0
# 4                                              849.0
#
#    China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# 0                                              821.0
# 1                                              821.0
# 2                                              821.0
# 3                                              810.0
# 4                                              810.0
#
# [5 rows x 54 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 521
# Data columns (total 54 columns):
# Unnamed: 0                                                           522 non-null datetime64[ns]
# 철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton                            502 non-null float64
# 중국 철광석 생산량10000 tons                                                 520 non-null float64
# 주요 중국 철광석 항구재고량mmt                                                   522 non-null float64
# Bloomberg(DJ-UBS) Commodity Index1991=100                            522 non-null float64
# Bloomberg Commodity Total Return1991=100                             522 non-null float64
# TR/CC CRB Index1967=100                                              522 non-null float64
# S&P GSCI1970=100                                                     522 non-null float64
# GSCI Energy1970=100                                                  394 non-null float64
# GSCI Petroleum1970=100                                               394 non-null float64
# GSCI Non-Energy1970=100                                              394 non-null float64
# GSCI Reduced Energy Index (CPW 2)1970=100                            394 non-null float64
# GSCI Light Energy Index (CPW 4)1970=100                              394 non-null float64
# GSCI Industrial Metals1970=100                                       394 non-null float64
# GSCI Precious Metals1970=100                                         394 non-null float64
# GSCI Agriculture1970=100                                             394 non-null float64
# GSCI Livestock1970=100                                               394 non-null float64
# GSCI Softs1970=100                                                   394 non-null float64
# Reuters Index of Commodity Prices1931.09.18=100                      445 non-null float64
# CRB BLS Spot Index1967=100                                           522 non-null float64
# PDS 원자재 지수2015.01.02=100                                             185 non-null float64
# PDS 귀금속 하위지수2015.01.02=100                                           185 non-null float64
# PDS 에너지 하위지수2015.01.02=100                                           185 non-null float64
# PDS 비철금속 하위지수2015.01.02=100                                          185 non-null float64
# PDS 철강 하위지수2015.01.02=100                                            185 non-null float64
# PDS 석유화학 하위지수2015.01.02=100                                          185 non-null float64
# PDS 농산물 하위지수2015.01.02=100                                           185 non-null float64
# LMEX Index1999.04=1000                                               522 non-null float64
# US Dollar IndexMar 1973=100                                          522 non-null float64
# DRAMeXchange Index (DXI)2001.10.01=1000                              522 non-null float64
# TOCOM Index2002.05.31=100                                            522 non-null float64
# Rogers International Commodities Index1998.07.31=1000                522 non-null float64
# Rogers International Commodities Index Energy1998.07.31=1000         522 non-null float64
# Rogers International Commodities Index Metals1998.07.31=1000         522 non-null float64
# Rogers International Commodities Index Agriculture1998.07.31=1000    522 non-null float64
# CNY/KRW (중국 인민폐 / 한국 원)                                              522 non-null float64
# USD/RMB (미국 달러 / 중국 인민폐)                                             522 non-null float64
# Baltic Dry Index (BDI)1985.01.04                                     522 non-null float64
# Baltic Capesize Index (BCI)1999.03.01                                522 non-null float64
# Baltic Panamax Index (BPI)1998.05.06                                 522 non-null float64
# Baltic Clean Tanker Index (BCTI)1998.08.03                           522 non-null float64
# Baltic Dirty Tanker Index (BDTI)1998.08.03                           522 non-null float64
# Baltic Supramax index (BSI)2005.01.01                                522 non-null float64
# Baltic Handysize Index (BHSI)2006.05.23                              522 non-null float64
# SSY/Pacific Capesize Index1997.1.6=4114                              522 non-null float64
# SSY/Atlantic Capesize Index1997.1.6=5000                             522 non-null float64
# Howe Robinson Container Index1997.1.15=1000                          522 non-null float64
# China Containerized Freight Index (CCFI)1998.1.1=1000                522 non-null float64
# Shanghai Containerized Freight Index (SCFI)2009.10.16=1000           457 non-null float64
# China Coastal Bulk Freight Index (CBFI)2000.1.1=1000                 522 non-null float64
# China Newbuilding Price Index (CNPI)2011.07.01=1000                  368 non-null float64
# China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000          368 non-null float64
# China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000          368 non-null float64
# China Container Newbuilding Price Index (CNCPI)2011.07.01=1000       368 non-null float64
# dtypes: datetime64[ns](1), float64(53)
# memory usage: 224.3 KB

# %%
df.columns=['date', 'target',
       '중국 철광석 생산량10000 tons', '주요 중국 철광석 항구재고량mmt',
       'Bloomberg(DJ-UBS) Commodity Index1991=100',
       'Bloomberg Commodity Total Return1991=100', 'TR/CC CRB Index1967=100',
       'S&P GSCI1970=100', 'GSCI Energy1970=100', 'GSCI Petroleum1970=100',
       'GSCI Non-Energy1970=100', 'GSCI Reduced Energy Index (CPW 2)1970=100',
       'GSCI Light Energy Index (CPW 4)1970=100',
       'GSCI Industrial Metals1970=100', 'GSCI Precious Metals1970=100',
       'GSCI Agriculture1970=100', 'GSCI Livestock1970=100',
       'GSCI Softs1970=100', 'Reuters Index of Commodity Prices1931.09.18=100',
       'CRB BLS Spot Index1967=100', 'PDS 원자재 지수2015.01.02=100',
       'PDS 귀금속 하위지수2015.01.02=100', 'PDS 에너지 하위지수2015.01.02=100',
       'PDS 비철금속 하위지수2015.01.02=100', 'PDS 철강 하위지수2015.01.02=100',
       'PDS 석유화학 하위지수2015.01.02=100', 'PDS 농산물 하위지수2015.01.02=100',
       'LMEX Index1999.04=1000', 'US Dollar IndexMar 1973=100',
       'DRAMeXchange Index (DXI)2001.10.01=1000', 'TOCOM Index2002.05.31=100',
       'Rogers International Commodities Index1998.07.31=1000',
       'Rogers International Commodities Index Energy1998.07.31=1000',
       'Rogers International Commodities Index Metals1998.07.31=1000',
       'Rogers International Commodities Index Agriculture1998.07.31=1000',
       'CNY/KRW (중국 인민폐 / 한국 원)', 'USD/RMB (미국 달러 / 중국 인민폐)',
       'Baltic Dry Index (BDI)1985.01.04',
       'Baltic Capesize Index (BCI)1999.03.01',
       'Baltic Panamax Index (BPI)1998.05.06',
       'Baltic Clean Tanker Index (BCTI)1998.08.03',
       'Baltic Dirty Tanker Index (BDTI)1998.08.03',
       'Baltic Supramax index (BSI)2005.01.01',
       'Baltic Handysize Index (BHSI)2006.05.23',
       'SSY/Pacific Capesize Index1997.1.6=4114',
       'SSY/Atlantic Capesize Index1997.1.6=5000',
       'Howe Robinson Container Index1997.1.15=1000',
       'China Containerized Freight Index (CCFI)1998.1.1=1000',
       'Shanghai Containerized Freight Index (SCFI)2009.10.16=1000',
       'China Coastal Bulk Freight Index (CBFI)2000.1.1=1000',
       'China Newbuilding Price Index (CNPI)2011.07.01=1000',
       'China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000',
       'China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000',
       'China Container Newbuilding Price Index (CNCPI)2011.07.01=1000']

# %%
df.isnull().sum()

## 일단 target에 missing value가 있으면 안되므로 나머지는 나중에 생각하고 target 해당 NA를 drop =====> 20개
# Out:
# date                                                                   0
# target                                                                20
# 중국 철광석 생산량10000 tons                                                   2
# 주요 중국 철광석 항구재고량mmt                                                     0
# Bloomberg(DJ-UBS) Commodity Index1991=100                              0
# Bloomberg Commodity Total Return1991=100                               0
# TR/CC CRB Index1967=100                                                0
# S&P GSCI1970=100                                                       0
# GSCI Energy1970=100                                                  128
# GSCI Petroleum1970=100                                               128
# GSCI Non-Energy1970=100                                              128
# GSCI Reduced Energy Index (CPW 2)1970=100                            128
# GSCI Light Energy Index (CPW 4)1970=100                              128
# GSCI Industrial Metals1970=100                                       128
# GSCI Precious Metals1970=100                                         128
# GSCI Agriculture1970=100                                             128
# GSCI Livestock1970=100                                               128
# GSCI Softs1970=100                                                   128
# Reuters Index of Commodity Prices1931.09.18=100                       77
# CRB BLS Spot Index1967=100                                             0
# PDS 원자재 지수2015.01.02=100                                             337
# PDS 귀금속 하위지수2015.01.02=100                                           337
# PDS 에너지 하위지수2015.01.02=100                                           337
# PDS 비철금속 하위지수2015.01.02=100                                          337
# PDS 철강 하위지수2015.01.02=100                                            337
# PDS 석유화학 하위지수2015.01.02=100                                          337
# PDS 농산물 하위지수2015.01.02=100                                           337
# LMEX Index1999.04=1000                                                 0
# US Dollar IndexMar 1973=100                                            0
# DRAMeXchange Index (DXI)2001.10.01=1000                                0
# TOCOM Index2002.05.31=100                                              0
# Rogers International Commodities Index1998.07.31=1000                  0
# Rogers International Commodities Index Energy1998.07.31=1000           0
# Rogers International Commodities Index Metals1998.07.31=1000           0
# Rogers International Commodities Index Agriculture1998.07.31=1000      0
# CNY/KRW (중국 인민폐 / 한국 원)                                                0
# USD/RMB (미국 달러 / 중국 인민폐)                                               0
# Baltic Dry Index (BDI)1985.01.04                                       0
# Baltic Capesize Index (BCI)1999.03.01                                  0
# Baltic Panamax Index (BPI)1998.05.06                                   0
# Baltic Clean Tanker Index (BCTI)1998.08.03                             0
# Baltic Dirty Tanker Index (BDTI)1998.08.03                             0
# Baltic Supramax index (BSI)2005.01.01                                  0
# Baltic Handysize Index (BHSI)2006.05.23                                0
# SSY/Pacific Capesize Index1997.1.6=4114                                0
# SSY/Atlantic Capesize Index1997.1.6=5000                               0
# Howe Robinson Container Index1997.1.15=1000                            0
# China Containerized Freight Index (CCFI)1998.1.1=1000                  0
# Shanghai Containerized Freight Index (SCFI)2009.10.16=1000            65
# China Coastal Bulk Freight Index (CBFI)2000.1.1=1000                   0
# China Newbuilding Price Index (CNPI)2011.07.01=1000                  154
# China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000          154
# China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000          154
# China Container Newbuilding Price Index (CNCPI)2011.07.01=1000       154
# dtype: int64

# %%
df=df.dropna(subset = ['target'])  #target에 NA 가 있으면 해당 행 삭제

# %%
df.describe()
# Out:
#            target  중국 철광석 생산량10000 tons  주요 중국 철광석 항구재고량mmt  \
# count  502.000000            502.000000          502.000000
# mean   102.087430          10542.773526           95.718247
# std     40.600486           2403.751681           25.575515
# min     38.720000           4723.680000           58.070000
# 25%     64.845000           8841.000000           72.470000
# 50%     92.525000          10922.400000           95.140000
# 75%    136.727500          12133.800000          108.170000
# max    190.540000          18415.800000          162.820000
#
#        Bloomberg(DJ-UBS) Commodity Index1991=100  \
# count                                 502.000000
# mean                                  118.004781
# std                                    26.190896
# min                                    73.800000
# 25%                                    88.402500
# 50%                                   125.255000
# 75%                                   137.605000
# max                                   173.950000
#
#        Bloomberg Commodity Total Return1991=100  TR/CC CRB Index1967=100  \
# count                                502.000000               502.000000
# mean                                 237.690139               252.994124
# std                                   52.100080                54.034152
# min                                  148.740000               157.790000
# 25%                                  178.942500               194.850000
# 50%                                  252.000000               268.000000
# 75%                                  277.042500               297.262500
# max                                  349.640000               367.090000
#
#        S&P GSCI1970=100  GSCI Energy1970=100  GSCI Petroleum1970=100  \
# count        502.000000           394.000000              394.000000
# mean         512.167610           256.237868              279.786320
# std          125.538209            80.401088               89.895263
# min          279.490000           103.750000              110.170000
# 25%          392.770000           175.840000              189.090000
# 50%          507.400000           282.960000              312.405000
# 75%          638.067500           332.585000              364.497500
# max          753.350000           383.480000              420.120000
#
#        GSCI Non-Energy1970=100  \
# count               394.000000
# mean                378.335000
# std                  58.450655
# min                 295.880000
# 25%                 327.775000
# 50%                 369.900000
# 75%                 427.932500
# max                 511.410000
#
#                                     ...                                \
# count                               ...
# mean                                ...
# std                                 ...
# min                                 ...
# 25%                                 ...
# 50%                                 ...
# 75%                                 ...
# max                                 ...
#
#        SSY/Pacific Capesize Index1997.1.6=4114  \
# count                               502.000000
# mean                               5385.692231
# std                                2301.232608
# min                                1594.000000
# 25%                                3953.500000
# 50%                                5023.500000
# 75%                                6312.500000
# max                               15800.000000
#
#        SSY/Atlantic Capesize Index1997.1.6=5000  \
# count                                502.000000
# mean                                6984.024900
# std                                 2869.695691
# min                                 2419.000000
# 25%                                 5185.000000
# 50%                                 6303.500000
# 75%                                 8392.250000
# max                                19896.000000
#
#        Howe Robinson Container Index1997.1.15=1000  \
# count                                   502.000000
# mean                                    542.625100
# std                                     140.813654
# min                                     329.600000
# 25%                                     451.000000
# 50%                                     504.050000
# 75%                                     615.750000
# max                                     916.100000
#
#        China Containerized Freight Index (CCFI)1998.1.1=1000  \
# count                                         502.000000
# mean                                          962.812231
# std                                           165.534440
# min                                           632.360000
# 25%                                           814.275000
# 50%                                           984.720000
# 75%                                          1096.922500
# max                                          1335.860000
#
#        Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# count                                         457.000000
# mean                                          983.727484
# std                                           257.985006
# min                                           400.430000
# 25%                                           797.620000
# 50%                                          1000.000000
# 75%                                          1133.000000
# max                                          1583.000000
#
#        China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# count                                         502.000000
# mean                                         1136.650458
# std                                           229.749929
# min                                           771.010000
# 25%                                           972.445000
# 50%                                          1140.270000
# 75%                                          1214.465000
# max                                          2115.440000
#
#        China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# count                                         368.000000
# mean                                          865.641304
# std                                            69.036275
# min                                           759.000000
# 25%                                           794.000000
# 50%                                           869.000000
# 75%                                           928.000000
# max                                          1000.000000
#
#        China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# count                                         368.000000
# mean                                          861.168478
# std                                            70.443352
# min                                           747.000000
# 25%                                           793.000000
# 50%                                           855.000000
# 75%                                           924.000000
# max                                          1000.000000
#
#        China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# count                                         368.000000
# mean                                          923.627717
# std                                            61.674499
# min                                           818.000000
# 25%                                           869.000000
# 50%                                           926.500000
# 75%                                           981.000000
# max                                          1003.000000
#
#        China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# count                                         368.000000
# mean                                          872.173913
# std                                            58.263212
# min                                           782.000000
# 25%                                           821.000000
# 50%                                           872.000000
# 75%                                           901.000000
# max                                          1011.000000
#
# [8 rows x 53 columns]

# %%
df.shape
# Out:
# (502, 54)

# %% [markdown]
# ### 데이터 주요 특성 시각화

# %% [markdown]
# #### 시간별 철광석 가격

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

plt.xticks(rotation=30, fontsize = 13)
plt.yticks(fontsize = 14)
plt.xlabel('날짜(일)', fontsize=14)
plt.ylabel('가격', fontsize=14, rotation = 0) 
plt.title('철광석 가격변동량', fontsize = 16)

ax.xaxis.set_label_coords(1.05, -0.025)
ax.yaxis.set_label_coords(-0.05, 1.0)

ax.grid(True) # 얇은 선 격자
plt.plot(df['target'])
plt.show()

# %% [markdown]
# ##### 보기 어렵다 연도별 월별 barplot 은 어떨까

# %%
df["year"] = df['date'].dt.year
df["month"] = df["date"].dt.month
df["day"] = df["date"].dt.day
df.shape
# Out:
# (502, 57)

# %%
figure, (ax1,ax2,ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(18,8)

sns.barplot(data=df, x="year", y="target", ax=ax1)
sns.barplot(data=df, x="month", y="target", ax=ax2)
sns.barplot(data=df, x="day", y="target", ax=ax3)

ax1.set(ylabel='target',title="연도")
ax2.set(xlabel='month',title="월별")
ax3.set(xlabel='day', title="일별")
# Out:
# [Text(0.5,0,'day'), Text(0.5,1,'일별')]

# %% [markdown]
# #### 연도별로 2013년이가격이 제일 높았고 17~18년 이 비슷하다 월별 추이를 봤을떄 7~9월 특히 8월 즉 여름시즌이 철광석 가격이 높은걸 알수 있다 6월은 뭔데 가격이 젤 낮을까??

# %% [markdown]
# ### 시차별 상관관계 구하기
# #### 상관관계
# #### 코사인유사도

# %%
df.date
# Out:
# 0     2018-07-09
# 1     2018-07-02
# 2     2018-06-25
# 3     2018-06-18
# 4     2018-06-11
# 5     2018-06-04
# 6     2018-05-28
# 7     2018-05-21
# 8     2018-05-14
# 9     2018-05-07
# 10    2018-04-30
# 11    2018-04-23
# 12    2018-04-16
# 13    2018-04-09
# 14    2018-04-02
# 15    2018-03-26
# 16    2018-03-19
# 17    2018-03-12
# 18    2018-03-05
# 19    2018-02-26
# 20    2018-02-19
# 21    2018-02-12
# 22    2018-02-05
# 23    2018-01-29
# 24    2018-01-22
# 25    2018-01-15
# 26    2018-01-08
# 27    2018-01-01
# 28    2017-12-25
# 29    2017-12-18
#          ...
# 472   2009-06-22
# 473   2009-06-15
# 474   2009-06-08
# 475   2009-06-01
# 476   2009-05-25
# 477   2009-05-18
# 478   2009-05-11
# 479   2009-05-04
# 480   2009-04-27
# 481   2009-04-20
# 482   2009-04-13
# 483   2009-04-06
# 484   2009-03-30
# 485   2009-03-23
# 486   2009-03-16
# 487   2009-03-09
# 488   2009-03-02
# 489   2009-02-23
# 490   2009-02-16
# 491   2009-02-09
# 492   2009-02-02
# 493   2009-01-26
# 494   2009-01-19
# 495   2009-01-12
# 496   2009-01-05
# 497   2008-12-29
# 498   2008-12-22
# 499   2008-12-15
# 500   2008-12-08
# 501   2008-12-01
# Name: date, Length: 502, dtype: datetime64[ns]

# %%
df.date.describe()
# Out:
# count                     502
# unique                    502
# top       2017-10-30 00:00:00
# freq                        1
# first     2008-12-01 00:00:00
# last      2018-07-09 00:00:00
# Name: date, dtype: object

# %%
df['target'][:]
# Out:
# 0      63.92
# 1      64.05
# 2      65.23
# 3      66.13
# 4      67.37
# 5      66.30
# 6      65.29
# 7      64.66
# 8      67.93
# 9      66.95
# 10     66.43
# 11     66.50
# 12     65.97
# 13     64.69
# 14     64.05
# 15     64.21
# 16     66.68
# 17     70.66
# 18     74.45
# 19     78.99
# 20     78.51
# 21     77.61
# 22     76.52
# 23     73.50
# 24     75.47
# 25     75.69
# 26     78.33
# 27     75.76
# 28     73.48
# 29     74.02
#        ...
# 472    76.05
# 473    74.94
# 474    72.24
# 475    68.31
# 476    64.45
# 477    64.15
# 478    63.67
# 479    61.38
# 480    60.31
# 481    58.73
# 482    59.23
# 483    59.96
# 484    60.48
# 485    59.70
# 486    62.47
# 487    62.37
# 488    64.81
# 489    69.04
# 490    74.98
# 491    81.86
# 492    78.83
# 493    74.25
# 494    73.34
# 495    74.09
# 496    73.64
# 497    72.54
# 498    76.43
# 499    74.15
# 500    69.38
# 501    65.82
# Name: target, Length: 502, dtype: float64

# %%
## 시차별 피어슨 상관관계 함수
def index_corr(df,week):
    index_1=df[df.date<=(df.date.max()- datetime.timedelta(days=(week*7)))]
    index_1 = index_1.drop(["date","target"], axis=1)
    index_1=index_1.reset_index(drop=True)
    
    if week == 0:
        target=df['target'][:]
    else :
        target=df['target'][:-week]
    total=pd.concat([target,index_1],axis=1)
    corr_total=total.corr()
    corr_target=corr_total['target']
    return corr_target

# %%
corr_t=[]
tn=[]
for i in range(0,30):
    t = index_corr(df,i)
    corr_t.append(t)
    tn.append('t-'+str(i)+'주')
corr_t = pd.DataFrame(corr_t)
corr_t.index=np.arange(0,30)
corr_t=corr_t.drop('target',1)
corr_t['시점']=tn

# %%
cols = corr_t.columns.tolist() 
cols = cols[-1:] + cols[:-1] # 마지막 열을 앞에 열로 보내기
corr_t=corr_t[cols]

# %%
corr_t
# Out:
#        시점  중국 철광석 생산량10000 tons  주요 중국 철광석 항구재고량mmt  \
# 0    t-0주             -0.133718           -0.406748
# 1    t-1주             -0.141067           -0.412392
# 2    t-2주             -0.146386           -0.417513
# 3    t-3주             -0.152845           -0.422103
# 4    t-4주             -0.160486           -0.426421
# 5    t-5주             -0.170552           -0.430995
# 6    t-6주             -0.180414           -0.435259
# 7    t-7주             -0.191719           -0.440008
# 8    t-8주             -0.203112           -0.445198
# 9    t-9주             -0.214477           -0.450520
# 10  t-10주             -0.227097           -0.455600
# 11  t-11주             -0.242242           -0.460274
# 12  t-12주             -0.256962           -0.465687
# 13  t-13주             -0.270376           -0.471324
# 14  t-14주             -0.282591           -0.477205
# 15  t-15주             -0.292494           -0.483785
# 16  t-16주             -0.302045           -0.490374
# 17  t-17주             -0.311644           -0.496808
# 18  t-18주             -0.319585           -0.503006
# 19  t-19주             -0.327770           -0.509058
# 20  t-20주             -0.336192           -0.515204
# 21  t-21주             -0.341019           -0.521186
# 22  t-22주             -0.347243           -0.526805
# 23  t-23주             -0.353328           -0.531810
# 24  t-24주             -0.361144           -0.536478
# 25  t-25주             -0.370881           -0.541394
# 26  t-26주             -0.379501           -0.546817
# 27  t-27주             -0.387453           -0.551820
# 28  t-28주             -0.396248           -0.556099
# 29  t-29주             -0.405075           -0.560267
#
#     Bloomberg(DJ-UBS) Commodity Index1991=100  \
# 0                                    0.880746
# 1                                    0.881856
# 2                                    0.881736
# 3                                    0.881066
# 4                                    0.880289
# 5                                    0.879165
# 6                                    0.877019
# 7                                    0.874368
# 8                                    0.871805
# 9                                    0.869248
# 10                                   0.866449
# 11                                   0.863180
# 12                                   0.859559
# 13                                   0.855723
# 14                                   0.852166
# 15                                   0.848671
# 16                                   0.845268
# 17                                   0.841055
# 18                                   0.835805
# 19                                   0.829907
# 20                                   0.823873
# 21                                   0.818071
# 22                                   0.812871
# 23                                   0.807431
# 24                                   0.801092
# 25                                   0.793382
# 26                                   0.785218
# 27                                   0.777232
# 28                                   0.769827
# 29                                   0.762692
#
#     Bloomberg Commodity Total Return1991=100  TR/CC CRB Index1967=100  \
# 0                                   0.882701                 0.868078
# 1                                   0.883724                 0.866861
# 2                                   0.883503                 0.864455
# 3                                   0.882729                 0.861695
# 4                                   0.881870                 0.858973
# 5                                   0.880658                 0.855955
# 6                                   0.878416                 0.851741
# 7                                   0.875666                 0.846803
# 8                                   0.873014                 0.841937
# 9                                   0.870355                 0.836962
# 10                                  0.867472                 0.831686
# 11                                  0.864130                 0.825837
# 12                                  0.860416                 0.819437
# 13                                  0.856479                 0.812698
# 14                                  0.852822                 0.806127
# 15                                  0.849180                 0.799538
# 16                                  0.845640                 0.793013
# 17                                  0.841297                 0.785459
# 18                                  0.835912                 0.777115
# 19                                  0.829852                 0.768289
# 20                                  0.823669                 0.759274
# 21                                  0.817707                 0.750389
# 22                                  0.812359                 0.742048
# 23                                  0.806784                 0.733419
# 24                                  0.800313                 0.724098
# 25                                  0.792454                 0.713592
# 26                                  0.784145                 0.702618
# 27                                  0.776011                 0.691785
# 28                                  0.768446                 0.681483
# 29                                  0.761165                 0.671527
#
#     S&P GSCI1970=100  GSCI Energy1970=100  GSCI Petroleum1970=100  \
# 0           0.841933             0.860540                0.859338
# 1           0.838805             0.858278                0.857210
# 2           0.834405             0.855776                0.854769
# 3           0.829796             0.853868                0.852820
# 4           0.825284             0.852355                0.851330
# 5           0.820375             0.850600                0.849613
# 6           0.814353             0.847896                0.846966
# 7           0.807604             0.844671                0.843813
# 8           0.800859             0.842365                0.841497
# 9           0.793591             0.839679                0.838838
# 10          0.785941             0.836313                0.835382
# 11          0.777646             0.831505                0.830605
# 12          0.768512             0.825428                0.824611
# 13          0.758770             0.818420                0.817744
# 14          0.748996             0.811600                0.811071
# 15          0.739186             0.805366                0.804931
# 16          0.729741             0.800178                0.799851
# 17          0.719242             0.794220                0.793950
# 18          0.707876             0.787764                0.787662
# 19          0.696076             0.781253                0.781317
# 20          0.684187             0.774403                0.774612
# 21          0.672443             0.767122                0.767516
# 22          0.661201             0.759970                0.760477
# 23          0.649630             0.752643                0.753228
# 24          0.637607             0.745162                0.745873
# 25          0.624399             0.736845                0.737802
# 26          0.610636             0.727776                0.728927
# 27          0.597191             0.718698                0.720047
# 28          0.584550             0.710532                0.712070
# 29          0.572674             0.703644                0.705268
#
#     GSCI Non-Energy1970=100    ...     \
# 0                  0.906347    ...
# 1                  0.905900    ...
# 2                  0.905273    ...
# 3                  0.904546    ...
# 4                  0.903569    ...
# 5                  0.901841    ...
# 6                  0.899250    ...
# 7                  0.896906    ...
# 8                  0.895599    ...
# 9                  0.895015    ...
# 10                 0.894804    ...
# 11                 0.894070    ...
# 12                 0.892534    ...
# 13                 0.890250    ...
# 14                 0.888070    ...
# 15                 0.885903    ...
# 16                 0.884701    ...
# 17                 0.883471    ...
# 18                 0.882271    ...
# 19                 0.880856    ...
# 20                 0.879245    ...
# 21                 0.877431    ...
# 22                 0.876475    ...
# 23                 0.875431    ...
# 24                 0.873831    ...
# 25                 0.870588    ...
# 26                 0.865990    ...
# 27                 0.861197    ...
# 28                 0.856731    ...
# 29                 0.852846    ...
#
#     China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 0                                            0.684236
# 1                                            0.679238
# 2                                            0.673717
# 3                                            0.667961
# 4                                            0.662189
# 5                                            0.657083
# 6                                            0.652057
# 7                                            0.647060
# 8                                            0.642205
# 9                                            0.636929
# 10                                           0.631174
# 11                                           0.625286
# 12                                           0.619428
# 13                                           0.613453
# 14                                           0.607589
# 15                                           0.602031
# 16                                           0.596798
# 17                                           0.592415
# 18                                           0.588953
# 19                                           0.586451
# 20                                           0.584804
# 21                                           0.583901
# 22                                           0.583318
# 23                                           0.582847
# 24                                           0.582330
# 25                                           0.581623
# 26                                           0.580308
# 27                                           0.577965
# 28                                           0.574326
# 29                                           0.570171
#
#     Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 0                                            0.699417
# 1                                            0.698472
# 2                                            0.696942
# 3                                            0.694895
# 4                                            0.692003
# 5                                            0.688927
# 6                                            0.686677
# 7                                            0.684732
# 8                                            0.682953
# 9                                            0.681736
# 10                                           0.680134
# 11                                           0.676913
# 12                                           0.674124
# 13                                           0.671763
# 14                                           0.669832
# 15                                           0.666884
# 16                                           0.663116
# 17                                           0.659682
# 18                                           0.657035
# 19                                           0.655873
# 20                                           0.656014
# 21                                           0.657971
# 22                                           0.661654
# 23                                           0.666939
# 24                                           0.673257
# 25                                           0.680327
# 26                                           0.688192
# 27                                           0.696071
# 28                                           0.702706
# 29                                           0.706337
#
#     China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 0                                            0.639485
# 1                                            0.646694
# 2                                            0.652656
# 3                                            0.655240
# 4                                            0.655776
# 5                                            0.656585
# 6                                            0.658969
# 7                                            0.662608
# 8                                            0.668237
# 9                                            0.675060
# 10                                           0.682082
# 11                                           0.689231
# 12                                           0.695881
# 13                                           0.700972
# 14                                           0.705755
# 15                                           0.710401
# 16                                           0.713404
# 17                                           0.713829
# 18                                           0.710743
# 19                                           0.704279
# 20                                           0.695538
# 21                                           0.685191
# 22                                           0.675617
# 23                                           0.667867
# 24                                           0.663150
# 25                                           0.662358
# 26                                           0.663194
# 27                                           0.665136
# 28                                           0.665885
# 29                                           0.668919
#
#     China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 0                                            0.528165
# 1                                            0.519334
# 2                                            0.510094
# 3                                            0.500733
# 4                                            0.490946
# 5                                            0.480990
# 6                                            0.470535
# 7                                            0.460003
# 8                                            0.448970
# 9                                            0.437578
# 10                                           0.425696
# 11                                           0.413503
# 12                                           0.401184
# 13                                           0.388967
# 14                                           0.376909
# 15                                           0.364788
# 16                                           0.353315
# 17                                           0.343339
# 18                                           0.335907
# 19                                           0.329403
# 20                                           0.321971
# 21                                           0.312838
# 22                                           0.304026
# 23                                           0.296116
# 24                                           0.287874
# 25                                           0.280115
# 26                                           0.272892
# 27                                           0.265653
# 28                                           0.258278
# 29                                           0.250873
#
#     China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 0                                            0.486744
# 1                                            0.477459
# 2                                            0.467661
# 3                                            0.457754
# 4                                            0.447416
# 5                                            0.436852
# 6                                            0.425702
# 7                                            0.414238
# 8                                            0.402001
# 9                                            0.389406
# 10                                           0.376183
# 11                                           0.362381
# 12                                           0.348411
# 13                                           0.334622
# 14                                           0.320954
# 15                                           0.307145
# 16                                           0.293907
# 17                                           0.282163
# 18                                           0.273081
# 19                                           0.264908
# 20                                           0.255789
# 21                                           0.244928
# 22                                           0.234518
# 23                                           0.225145
# 24                                           0.215402
# 25                                           0.206144
# 26                                           0.197468
# 27                                           0.188783
# 28                                           0.180006
# 29                                           0.171217
#
#     China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 0                                            0.288315
# 1                                            0.279572
# 2                                            0.270411
# 3                                            0.261297
# 4                                            0.251873
# 5                                            0.242530
# 6                                            0.232778
# 7                                            0.223030
# 8                                            0.212707
# 9                                            0.202048
# 10                                           0.190961
# 11                                           0.179762
# 12                                           0.168390
# 13                                           0.156935
# 14                                           0.145455
# 15                                           0.133814
# 16                                           0.122747
# 17                                           0.112687
# 18                                           0.104639
# 19                                           0.097277
# 20                                           0.089245
# 21                                           0.079896
# 22                                           0.070830
# 23                                           0.062350
# 24                                           0.053774
# 25                                           0.045430
# 26                                           0.037545
# 27                                           0.029888
# 28                                           0.022273
# 29                                           0.014698
#
#     China Container Newbuilding Price Index (CNCPI)2011.07.01=1000      year  \
# 0                                            0.577547              -0.568661
# 1                                            0.570719              -0.574813
# 2                                            0.563763              -0.580600
# 3                                            0.556682              -0.585854
# 4                                            0.549349              -0.590821
# 5                                            0.542110              -0.596492
# 6                                            0.534507              -0.602313
# 7                                            0.526925              -0.608323
# 8                                            0.518918              -0.614209
# 9                                            0.510580              -0.619809
# 10                                           0.502082              -0.624411
# 11                                           0.493614              -0.628529
# 12                                           0.484892              -0.633552
# 13                                           0.476337              -0.639376
# 14                                           0.468184              -0.646022
# 15                                           0.460332              -0.653289
# 16                                           0.453684              -0.660658
# 17                                           0.449107              -0.668311
# 18                                           0.447354              -0.675875
# 19                                           0.446542              -0.683125
# 20                                           0.445019              -0.689931
# 21                                           0.441848              -0.696143
# 22                                           0.439049              -0.702192
# 23                                           0.437409              -0.708303
# 24                                           0.435792              -0.714281
# 25                                           0.434679              -0.720238
# 26                                           0.434184              -0.726261
# 27                                           0.433504              -0.731617
# 28                                           0.432597              -0.736732
# 29                                           0.431913              -0.741428
#
#        month       day
# 0  -0.049050  0.005917
# 1  -0.039900  0.006071
# 2  -0.031622  0.013752
# 3  -0.023931  0.019884
# 4  -0.015933  0.011020
# 5  -0.005701  0.003280
# 6   0.005585  0.007057
# 7   0.018287  0.014864
# 8   0.029643  0.009227
# 9   0.039057 -0.000452
# 10  0.042296  0.000575
# 11  0.042567  0.013077
# 12  0.044652  0.019689
# 13  0.049003  0.009375
# 14  0.055504  0.003911
# 15  0.063505  0.009672
# 16  0.071840  0.016115
# 17  0.079979  0.010311
# 18  0.087388  0.004985
# 19  0.089367  0.013929
# 20  0.085570  0.024071
# 21  0.076416  0.016453
# 22  0.067082  0.005590
# 23  0.058027  0.003911
# 24  0.048530  0.016003
# 25  0.039392  0.019121
# 26  0.031387  0.010955
# 27  0.020650  0.006121
# 28  0.010414  0.012207
# 29  0.007889  0.020669
#
# [30 rows x 56 columns]

# %% [markdown]
# #### 시점별 선행변수를 추려보자 if T 시점 --  max(all시점) then T 시점은 선행변수

# %%
def check_t(corr_t,value):
    qq=[]
    for i in range(0,(len(corr_t.iloc[:,1])-1)):
        if abs(corr_t.iloc[:,value][i]) == abs(max(corr_t.iloc[:,value])):
            qq = ('t-'+str(i)+'주')
    return qq

# %%
check=[]
for k in range(1,56):
    a= check_t(corr_t,k)
    if a == []:
        a = ['선행시점없음']
    check.append(a)
pre_corr=pd.DataFrame(check,corr_t.columns[1:],columns=['피어슨선행시점'])#### []공백으로 나오는건 마지막시점이 가장 max 일 경우 즉 쓸데없음
pre_corr
# Out:
#                                                      피어슨선행시점
# 중국 철광석 생산량10000 tons                                    t-0주
# 주요 중국 철광석 항구재고량mmt                                      t-0주
# Bloomberg(DJ-UBS) Commodity Index1991=100               t-1주
# Bloomberg Commodity Total Return1991=100                t-1주
# TR/CC CRB Index1967=100                                 t-0주
# S&P GSCI1970=100                                        t-0주
# GSCI Energy1970=100                                     t-0주
# GSCI Petroleum1970=100                                  t-0주
# GSCI Non-Energy1970=100                                 t-0주
# GSCI Reduced Energy Index (CPW 2)1970=100               t-0주
# GSCI Light Energy Index (CPW 4)1970=100                 t-0주
# GSCI Industrial Metals1970=100                          t-4주
# GSCI Precious Metals1970=100                           t-21주
# GSCI Agriculture1970=100                               t-24주
# GSCI Livestock1970=100                                  t-0주
# GSCI Softs1970=100                                      t-3주
# Reuters Index of Commodity Prices1931.09.18=100         t-1주
# CRB BLS Spot Index1967=100                              t-0주
# PDS 원자재 지수2015.01.02=100                                t-0주
# PDS 귀금속 하위지수2015.01.02=100                             t-21주
# PDS 에너지 하위지수2015.01.02=100                              t-0주
# PDS 비철금속 하위지수2015.01.02=100                             t-0주
# PDS 철강 하위지수2015.01.02=100                               t-0주
# PDS 석유화학 하위지수2015.01.02=100                             t-0주
# PDS 농산물 하위지수2015.01.02=100                              t-0주
# LMEX Index1999.04=1000                                  t-3주
# US Dollar IndexMar 1973=100                         [선행시점없음]
# DRAMeXchange Index (DXI)2001.10.01=1000                 t-0주
# TOCOM Index2002.05.31=100                               t-0주
# Rogers International Commodities Index1998.07.3...      t-0주
# Rogers International Commodities Index Energy19...      t-0주
# Rogers International Commodities Index Metals19...      t-2주
# Rogers International Commodities Index Agricult...      t-0주
# CNY/KRW (중국 인민폐 / 한국 원)                             [선행시점없음]
# USD/RMB (미국 달러 / 중국 인민폐)                            [선행시점없음]
# Baltic Dry Index (BDI)1985.01.04                    [선행시점없음]
# Baltic Capesize Index (BCI)1999.03.01               [선행시점없음]
# Baltic Panamax Index (BPI)1998.05.06                [선행시점없음]
# Baltic Clean Tanker Index (BCTI)1998.08.03              t-0주
# Baltic Dirty Tanker Index (BDTI)1998.08.03              t-6주
# Baltic Supramax index (BSI)2005.01.01               [선행시점없음]
# Baltic Handysize Index (BHSI)2006.05.23             [선행시점없음]
# SSY/Pacific Capesize Index1997.1.6=4114                t-22주
# SSY/Atlantic Capesize Index1997.1.6=5000               t-24주
# Howe Robinson Container Index1997.1.15=1000             t-0주
# China Containerized Freight Index (CCFI)1998.1....      t-0주
# Shanghai Containerized Freight Index (SCFI)2009...  [선행시점없음]
# China Coastal Bulk Freight Index (CBFI)2000.1.1...     t-17주
# China Newbuilding Price Index (CNPI)2011.07.01=...      t-0주
# China Bulker Newbuilding Price Index (CNDPI)201...      t-0주
# China Tanker Newbuilding Price Index (CNTPI)201...      t-0주
# China Container Newbuilding Price Index (CNCPI)...      t-0주
# year                                                    t-0주
# month                                                  t-19주
# day                                                    t-20주

# %% [markdown]
# #### 이제 시점별 상관관계변화를 한번 시각화해보자

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

plt.xticks(rotation=30, fontsize = 13)
plt.yticks(fontsize = 14)
plt.xlabel('시점', fontsize=14)
plt.ylabel('상관관계', fontsize=14, rotation = 0) 
plt.title('시점별 피어슨 상관관계', fontsize = 16)

ax.grid(True) # 얇은 선 격자
plt.plot(corr_t.iloc[:,1:])
plt.show()

# %% [markdown]
# #### 보통 T 시점보다 T-n 시점이 상관관계가 높을경우 선행지표라고 한다

# %%
## 상관관계가 +- 0.8 이상인것들
corr_df[-0.8 > corr_df.target]['target']
# Out:
# US Dollar IndexMar 1973=100   -0.828199
# Name: target, dtype: float64

# %%
corr_df[0.8< corr_df.target]['target']
# Out:
# target                                                               1.000000
# Bloomberg(DJ-UBS) Commodity Index1991=100                            0.803179
# Bloomberg Commodity Total Return1991=100                             0.806498
# S&P GSCI1970=100                                                     0.867018
# GSCI Energy1970=100                                                  0.868512
# GSCI Petroleum1970=100                                               0.869136
# GSCI Reduced Energy Index (CPW 2)1970=100                            0.863242
# GSCI Light Energy Index (CPW 4)1970=100                              0.855436
# GSCI Agriculture1970=100                                             0.807769
# Reuters Index of Commodity Prices1931.09.18=100                      0.803909
# 철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton.1                          1.000000
# Rogers International Commodities Index1998.07.31=1000                0.831952
# Rogers International Commodities Index Energy1998.07.31=1000         0.813489
# Rogers International Commodities Index Agriculture1998.07.31=1000    0.803178
# 철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton.2                          1.000000
# 철광석 Fines (Daily) [중국(수입가 CFR)] 현물USD/ton.3                          1.000000
# Name: target, dtype: float64

# %% [markdown]
# #### 코사인유사도

# %%
# 정규화

def normalize(matrix):
    matrix= (matrix-np.mean(matrix))/np.std(matrix)
    return matrix

# %%
def cos_sim (n,week):
    index_1=df[df.date<=(df.date.max()- datetime.timedelta(days=(week*7)))]
    index_1 = index_1.drop(["date","target"], axis=1)
    index_1=index_1.reset_index(drop=True)
    
    
    if week == 0:
        target=df['target'][:]
    else :
        target=df['target'][:-week]
    
    total=pd.concat([target,index_1],axis=1)
    total=total.dropna() ## 코사인유사도 이거 NA값들 싹다 제거해도 되나??
    tmp_target = total['target'].values.reshape(1,-1)
    tmp_target = normalize(tmp_target)
    tmp_index = total.iloc[:,n].values.reshape(1,-1)
    tmp_index = normalize(tmp_index)
    cos_t = cosine_similarity(tmp_target,tmp_index)
    return cos_t

# %%
def cos_sim_value (n):
    

    cos=[]
    for i in range(0,30):
        cos1 = cos_sim (n,i)[0]
        cos.append(cos1)
    cos = pd.DataFrame(cos)
    return cos

# %%
cos_total=cos_sim_value(1)
for j in range(2,56):
    cos2 = cos_sim_value(j)
    cos_total= pd.concat([cos_total,cos2],axis=1)
cos_total.columns=['중국 철광석 생산량10000 tons', '주요 중국 철광석 항구재고량mmt',
       'Bloomberg(DJ-UBS) Commodity Index1991=100',
       'Bloomberg Commodity Total Return1991=100', 'TR/CC CRB Index1967=100',
       'S&P GSCI1970=100', 'GSCI Energy1970=100', 'GSCI Petroleum1970=100',
       'GSCI Non-Energy1970=100', 'GSCI Reduced Energy Index (CPW 2)1970=100',
       'GSCI Light Energy Index (CPW 4)1970=100',
       'GSCI Industrial Metals1970=100', 'GSCI Precious Metals1970=100',
       'GSCI Agriculture1970=100', 'GSCI Livestock1970=100',
       'GSCI Softs1970=100', 'Reuters Index of Commodity Prices1931.09.18=100',
       'CRB BLS Spot Index1967=100', 'PDS 원자재 지수2015.01.02=100',
       'PDS 귀금속 하위지수2015.01.02=100', 'PDS 에너지 하위지수2015.01.02=100',
       'PDS 비철금속 하위지수2015.01.02=100', 'PDS 철강 하위지수2015.01.02=100',
       'PDS 석유화학 하위지수2015.01.02=100', 'PDS 농산물 하위지수2015.01.02=100',
       'LMEX Index1999.04=1000', 'US Dollar IndexMar 1973=100',
       'DRAMeXchange Index (DXI)2001.10.01=1000', 'TOCOM Index2002.05.31=100',
       'Rogers International Commodities Index1998.07.31=1000',
       'Rogers International Commodities Index Energy1998.07.31=1000',
       'Rogers International Commodities Index Metals1998.07.31=1000',
       'Rogers International Commodities Index Agriculture1998.07.31=1000',
       'CNY/KRW (중국 인민폐 / 한국 원)', 'USD/RMB (미국 달러 / 중국 인민폐)',
       'Baltic Dry Index (BDI)1985.01.04',
       'Baltic Capesize Index (BCI)1999.03.01',
       'Baltic Panamax Index (BPI)1998.05.06',
       'Baltic Clean Tanker Index (BCTI)1998.08.03',
       'Baltic Dirty Tanker Index (BDTI)1998.08.03',
       'Baltic Supramax index (BSI)2005.01.01',
       'Baltic Handysize Index (BHSI)2006.05.23',
       'SSY/Pacific Capesize Index1997.1.6=4114',
       'SSY/Atlantic Capesize Index1997.1.6=5000',
       'Howe Robinson Container Index1997.1.15=1000',
       'China Containerized Freight Index (CCFI)1998.1.1=1000',
       'Shanghai Containerized Freight Index (SCFI)2009.10.16=1000',
       'China Coastal Bulk Freight Index (CBFI)2000.1.1=1000',
       'China Newbuilding Price Index (CNPI)2011.07.01=1000',
       'China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000',
       'China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000',
       'China Container Newbuilding Price Index (CNCPI)2011.07.01=1000',
       'year', 'month', 'day']

# %%
cos_total['시점']=tn
cols = cos_total.columns.tolist() 
cols = cols[-1:] + cols[:-1] # 마지막 열을 앞에 열로 보내기
cos_total=cos_total[cols]
cos_total
# Out:
#        시점  중국 철광석 생산량10000 tons  주요 중국 철광석 항구재고량mmt  \
# 0    t-0주             -0.051196            0.552844
# 1    t-1주             -0.007377            0.555141
# 2    t-2주              0.036021            0.558005
# 3    t-3주              0.060103            0.559153
# 4    t-4주              0.072693            0.558441
# 5    t-5주              0.065591            0.557026
# 6    t-6주              0.058442            0.555201
# 7    t-7주              0.044687            0.550957
# 8    t-8주              0.035131            0.545567
# 9    t-9주              0.035805            0.538037
# 10  t-10주              0.025891            0.529514
# 11  t-11주              0.002723            0.523032
# 12  t-12주             -0.020479            0.515703
# 13  t-13주             -0.060827            0.512448
# 14  t-14주             -0.110656            0.509924
# 15  t-15주             -0.147409            0.506955
# 16  t-16주             -0.186298            0.505160
# 17  t-17주             -0.207703            0.505264
# 18  t-18주             -0.195211            0.505864
# 19  t-19주             -0.176786            0.508541
# 20  t-20주             -0.132258            0.513689
# 21  t-21주             -0.090804            0.515105
# 22  t-22주             -0.054169            0.517904
# 23  t-23주             -0.005292            0.522561
# 24  t-24주              0.035856            0.527499
# 25  t-25주              0.068326            0.530160
# 26  t-26주              0.103026            0.531392
# 27  t-27주              0.115275            0.530822
# 28  t-28주              0.108697            0.529591
# 29  t-29주              0.094244            0.525923
#
#     Bloomberg(DJ-UBS) Commodity Index1991=100  \
# 0                                    0.135899
# 1                                    0.103088
# 2                                    0.070509
# 3                                    0.041777
# 4                                    0.013882
# 5                                   -0.009523
# 6                                   -0.039095
# 7                                   -0.072187
# 8                                   -0.108648
# 9                                   -0.140286
# 10                                  -0.165532
# 11                                  -0.183963
# 12                                  -0.202791
# 13                                  -0.218126
# 14                                  -0.226328
# 15                                  -0.229101
# 16                                  -0.231091
# 17                                  -0.243086
# 18                                  -0.261061
# 19                                  -0.279202
# 20                                  -0.298842
# 21                                  -0.312813
# 22                                  -0.330836
# 23                                  -0.352756
# 24                                  -0.379164
# 25                                  -0.404366
# 26                                  -0.428205
# 27                                  -0.446882
# 28                                  -0.460091
# 29                                  -0.472542
#
#     Bloomberg Commodity Total Return1991=100  TR/CC CRB Index1967=100  \
# 0                                   0.171022                 0.118790
# 1                                   0.137576                 0.084177
# 2                                   0.104383                 0.049761
# 3                                   0.074976                 0.020323
# 4                                   0.046381                -0.008659
# 5                                   0.022171                -0.031249
# 6                                  -0.008292                -0.059799
# 7                                  -0.042362                -0.093117
# 8                                  -0.079802                -0.130197
# 9                                  -0.112438                -0.161740
# 10                                 -0.138694                -0.186129
# 11                                 -0.158102                -0.203616
# 12                                 -0.177937                -0.220911
# 13                                 -0.194267                -0.235489
# 14                                 -0.203397                -0.243677
# 15                                 -0.206999                -0.245964
# 16                                 -0.209786                -0.247786
# 17                                 -0.222633                -0.262785
# 18                                 -0.241456                -0.284975
# 19                                 -0.260380                -0.307054
# 20                                 -0.280789                -0.330176
# 21                                 -0.295515                -0.347211
# 22                                 -0.314227                -0.367716
# 23                                 -0.336844                -0.392213
# 24                                 -0.364084                -0.422181
# 25                                 -0.390169                -0.450916
# 26                                 -0.414849                -0.476381
# 27                                 -0.434322                -0.495834
# 28                                 -0.448396                -0.509980
# 29                                 -0.461629                -0.520987
#
#     S&P GSCI1970=100  GSCI Energy1970=100  GSCI Petroleum1970=100  \
# 0           0.487035             0.475849                0.458970
# 1           0.466418             0.458419                0.441723
# 2           0.445410             0.440538                0.423686
# 3           0.425713             0.424055                0.406563
# 4           0.402577             0.403183                0.384549
# 5           0.382130             0.384740                0.364906
# 6           0.356741             0.362660                0.341769
# 7           0.327245             0.336229                0.314240
# 8           0.296324             0.309506                0.286511
# 9           0.268203             0.285857                0.262428
# 10          0.243369             0.265619                0.241720
# 11          0.220781             0.247173                0.222818
# 12          0.195653             0.225722                0.201155
# 13          0.170478             0.202358                0.177729
# 14          0.146734             0.178942                0.154219
# 15          0.127414             0.158907                0.134519
# 16          0.110358             0.140515                0.117093
# 17          0.084172             0.112841                0.090418
# 18          0.054621             0.081194                0.060029
# 19          0.028259             0.053104                0.033044
# 20          0.004205             0.028693                0.009369
# 21         -0.015325             0.007668               -0.011374
# 22         -0.035289            -0.014038               -0.032534
# 23         -0.058727            -0.039874               -0.057433
# 24         -0.087785            -0.071412               -0.087968
# 25         -0.118832            -0.105420               -0.121217
# 26         -0.147513            -0.135284               -0.150907
# 27         -0.173984            -0.163205               -0.178824
# 28         -0.201173            -0.193117               -0.209538
# 29         -0.223673            -0.217259               -0.234634
#
#     GSCI Non-Energy1970=100    ...     \
# 0                  0.465100    ...
# 1                  0.435877    ...
# 2                  0.407505    ...
# 3                  0.378413    ...
# 4                  0.348337    ...
# 5                  0.321047    ...
# 6                  0.282271    ...
# 7                  0.241301    ...
# 8                  0.194268    ...
# 9                  0.149669    ...
# 10                 0.106884    ...
# 11                 0.067923    ...
# 12                 0.029922    ...
# 13                 0.000598    ...
# 14                -0.019900    ...
# 15                -0.031124    ...
# 16                -0.037062    ...
# 17                -0.050483    ...
# 18                -0.064640    ...
# 19                -0.077958    ...
# 20                -0.095775    ...
# 21                -0.104400    ...
# 22                -0.112439    ...
# 23                -0.119485    ...
# 24                -0.130006    ...
# 25                -0.139646    ...
# 26                -0.155936    ...
# 27                -0.169030    ...
# 28                -0.176779    ...
# 29                -0.186053    ...
#
#     China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 0                                            0.208543
# 1                                            0.190864
# 2                                            0.169917
# 3                                            0.147173
# 4                                            0.122101
# 5                                            0.101414
# 6                                            0.080091
# 7                                            0.058413
# 8                                            0.030649
# 9                                           -0.000978
# 10                                          -0.031560
# 11                                          -0.056544
# 12                                          -0.080789
# 13                                          -0.104682
# 14                                          -0.122552
# 15                                          -0.138941
# 16                                          -0.160213
# 17                                          -0.186338
# 18                                          -0.215566
# 19                                          -0.243372
# 20                                          -0.266545
# 21                                          -0.277404
# 22                                          -0.288811
# 23                                          -0.301127
# 24                                          -0.316955
# 25                                          -0.330900
# 26                                          -0.347988
# 27                                          -0.364507
# 28                                          -0.372243
# 29                                          -0.382751
#
#     Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 0                                            0.533711
# 1                                            0.529974
# 2                                            0.526277
# 3                                            0.526711
# 4                                            0.522616
# 5                                            0.513663
# 6                                            0.497366
# 7                                            0.478505
# 8                                            0.458876
# 9                                            0.440134
# 10                                           0.421648
# 11                                           0.393797
# 12                                           0.373516
# 13                                           0.355207
# 14                                           0.349208
# 15                                           0.348684
# 16                                           0.335177
# 17                                           0.312755
# 18                                           0.276875
# 19                                           0.241673
# 20                                           0.197509
# 21                                           0.163522
# 22                                           0.134425
# 23                                           0.121836
# 24                                           0.110038
# 25                                           0.106400
# 26                                           0.104268
# 27                                           0.098219
# 28                                           0.100738
# 29                                           0.091431
#
#     China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 0                                            0.576181
# 1                                            0.591416
# 2                                            0.604150
# 3                                            0.607675
# 4                                            0.604813
# 5                                            0.594396
# 6                                            0.583168
# 7                                            0.572980
# 8                                            0.565497
# 9                                            0.559132
# 10                                           0.554662
# 11                                           0.552272
# 12                                           0.546733
# 13                                           0.539144
# 14                                           0.535110
# 15                                           0.533965
# 16                                           0.531158
# 17                                           0.523697
# 18                                           0.510582
# 19                                           0.489809
# 20                                           0.468275
# 21                                           0.440040
# 22                                           0.406115
# 23                                           0.372636
# 24                                           0.343767
# 25                                           0.317849
# 26                                           0.291821
# 27                                           0.269271
# 28                                           0.250564
# 29                                           0.240187
#
#     China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 0                                           -0.515971
# 1                                           -0.534723
# 2                                           -0.553947
# 3                                           -0.568245
# 4                                           -0.580828
# 5                                           -0.587694
# 6                                           -0.594112
# 7                                           -0.599404
# 8                                           -0.607377
# 9                                           -0.614308
# 10                                          -0.619966
# 11                                          -0.623443
# 12                                          -0.625325
# 13                                          -0.625310
# 14                                          -0.621943
# 15                                          -0.617935
# 16                                          -0.615651
# 17                                          -0.615807
# 18                                          -0.620019
# 19                                          -0.625839
# 20                                          -0.633599
# 21                                          -0.637469
# 22                                          -0.644064
# 23                                          -0.652226
# 24                                          -0.660938
# 25                                          -0.666351
# 26                                          -0.670655
# 27                                          -0.670630
# 28                                          -0.663309
# 29                                          -0.656839
#
#     China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 0                                           -0.417142
# 1                                           -0.440164
# 2                                           -0.463993
# 3                                           -0.481515
# 4                                           -0.497095
# 5                                           -0.507046
# 6                                           -0.516578
# 7                                           -0.525273
# 8                                           -0.537897
# 9                                           -0.549205
# 10                                          -0.559397
# 11                                          -0.567426
# 12                                          -0.572663
# 13                                          -0.575735
# 14                                          -0.574895
# 15                                          -0.573305
# 16                                          -0.574526
# 17                                          -0.578943
# 18                                          -0.588749
# 19                                          -0.600674
# 20                                          -0.615186
# 21                                          -0.624522
# 22                                          -0.636875
# 23                                          -0.650134
# 24                                          -0.663884
# 25                                          -0.673998
# 26                                          -0.682220
# 27                                          -0.685248
# 28                                          -0.678920
# 29                                          -0.673583
#
#     China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 0                                           -0.597642
# 1                                           -0.609511
# 2                                           -0.621969
# 3                                           -0.630589
# 4                                           -0.637640
# 5                                           -0.640386
# 6                                           -0.642847
# 7                                           -0.644211
# 8                                           -0.646895
# 9                                           -0.648930
# 10                                          -0.650095
# 11                                          -0.649746
# 12                                          -0.648884
# 13                                          -0.647119
# 14                                          -0.643471
# 15                                          -0.640055
# 16                                          -0.637368
# 17                                          -0.636051
# 18                                          -0.636779
# 19                                          -0.638297
# 20                                          -0.641304
# 21                                          -0.641557
# 22                                          -0.643190
# 23                                          -0.646430
# 24                                          -0.650016
# 25                                          -0.651150
# 26                                          -0.651370
# 27                                          -0.648288
# 28                                          -0.640775
# 29                                          -0.633428
#
#     China Container Newbuilding Price Index (CNCPI)2011.07.01=1000      year  \
# 0                                           -0.597001               0.543603
# 1                                           -0.611776               0.549042
# 2                                           -0.626144               0.555201
# 3                                           -0.637383               0.559056
# 4                                           -0.647432               0.563160
# 5                                           -0.652871               0.562186
# 6                                           -0.657447               0.558426
# 7                                           -0.661195               0.548868
# 8                                           -0.666531               0.538525
# 9                                           -0.670868               0.527714
# 10                                          -0.674253               0.516385
# 11                                          -0.676163               0.505694
# 12                                          -0.677549               0.496128
# 13                                          -0.676970               0.493571
# 14                                          -0.674692               0.489363
# 15                                          -0.672178               0.483701
# 16                                          -0.670407               0.477286
# 17                                          -0.668761               0.471664
# 18                                          -0.668656               0.471750
# 19                                          -0.668695               0.478176
# 20                                          -0.668588               0.488874
# 21                                          -0.666314               0.498908
# 22                                          -0.665294               0.514657
# 23                                          -0.665208               0.531286
# 24                                          -0.664175               0.552058
# 25                                          -0.660182               0.570479
# 26                                          -0.654923               0.585854
# 27                                          -0.647115               0.603492
# 28                                          -0.635943               0.609456
# 29                                          -0.625029               0.607006
#
#        month       day
# 0  -0.181878 -0.009997
# 1  -0.163607  0.002223
# 2  -0.144926  0.011902
# 3  -0.125284  0.024482
# 4  -0.111286  0.042280
# 5  -0.090200  0.035942
# 6  -0.061932  0.042152
# 7  -0.012030  0.025015
# 8   0.044538  0.015094
# 9   0.099781  0.006754
# 10  0.151766 -0.004832
# 11  0.192079 -0.006877
# 12  0.223646 -0.001267
# 13  0.230937 -0.019317
# 14  0.233828 -0.033047
# 15  0.235123 -0.018131
# 16  0.244260 -0.019093
# 17  0.257139 -0.010241
# 18  0.263317 -0.024142
# 19  0.252233 -0.012050
# 20  0.236509 -0.004634
# 21  0.214455  0.006550
# 22  0.185740  0.007288
# 23  0.161191  0.001136
# 24  0.128881  0.003315
# 25  0.097524  0.017174
# 26  0.076636  0.016281
# 27  0.043155  0.007294
# 28  0.026865  0.004167
# 29  0.012843  0.002739
#
# [30 rows x 56 columns]

# %%
check_cos=[]
for k in range(1,56):
    a= check_t(cos_total,k)
    if a == []:
        a = ['선행시점없음']
    check_cos.append(a)
pre_cos=pd.DataFrame(check,cos_total.columns[1:],columns=['코사인선행시점'])#### []공백으로 나오는건 마지막시점이 가장 max 일 경우 즉 쓸데없음
pd.concat([pre_corr,pre_cos],axis=1)
# Out:
#                                                      피어슨선행시점   코사인선행시점
# 중국 철광석 생산량10000 tons                                    t-0주      t-0주
# 주요 중국 철광석 항구재고량mmt                                      t-0주      t-0주
# Bloomberg(DJ-UBS) Commodity Index1991=100               t-1주      t-1주
# Bloomberg Commodity Total Return1991=100                t-1주      t-1주
# TR/CC CRB Index1967=100                                 t-0주      t-0주
# S&P GSCI1970=100                                        t-0주      t-0주
# GSCI Energy1970=100                                     t-0주      t-0주
# GSCI Petroleum1970=100                                  t-0주      t-0주
# GSCI Non-Energy1970=100                                 t-0주      t-0주
# GSCI Reduced Energy Index (CPW 2)1970=100               t-0주      t-0주
# GSCI Light Energy Index (CPW 4)1970=100                 t-0주      t-0주
# GSCI Industrial Metals1970=100                          t-4주      t-4주
# GSCI Precious Metals1970=100                           t-21주     t-21주
# GSCI Agriculture1970=100                               t-24주     t-24주
# GSCI Livestock1970=100                                  t-0주      t-0주
# GSCI Softs1970=100                                      t-3주      t-3주
# Reuters Index of Commodity Prices1931.09.18=100         t-1주      t-1주
# CRB BLS Spot Index1967=100                              t-0주      t-0주
# PDS 원자재 지수2015.01.02=100                                t-0주      t-0주
# PDS 귀금속 하위지수2015.01.02=100                             t-21주     t-21주
# PDS 에너지 하위지수2015.01.02=100                              t-0주      t-0주
# PDS 비철금속 하위지수2015.01.02=100                             t-0주      t-0주
# PDS 철강 하위지수2015.01.02=100                               t-0주      t-0주
# PDS 석유화학 하위지수2015.01.02=100                             t-0주      t-0주
# PDS 농산물 하위지수2015.01.02=100                              t-0주      t-0주
# LMEX Index1999.04=1000                                  t-3주      t-3주
# US Dollar IndexMar 1973=100                         [선행시점없음]  [선행시점없음]
# DRAMeXchange Index (DXI)2001.10.01=1000                 t-0주      t-0주
# TOCOM Index2002.05.31=100                               t-0주      t-0주
# Rogers International Commodities Index1998.07.3...      t-0주      t-0주
# Rogers International Commodities Index Energy19...      t-0주      t-0주
# Rogers International Commodities Index Metals19...      t-2주      t-2주
# Rogers International Commodities Index Agricult...      t-0주      t-0주
# CNY/KRW (중국 인민폐 / 한국 원)                             [선행시점없음]  [선행시점없음]
# USD/RMB (미국 달러 / 중국 인민폐)                            [선행시점없음]  [선행시점없음]
# Baltic Dry Index (BDI)1985.01.04                    [선행시점없음]  [선행시점없음]
# Baltic Capesize Index (BCI)1999.03.01               [선행시점없음]  [선행시점없음]
# Baltic Panamax Index (BPI)1998.05.06                [선행시점없음]  [선행시점없음]
# Baltic Clean Tanker Index (BCTI)1998.08.03              t-0주      t-0주
# Baltic Dirty Tanker Index (BDTI)1998.08.03              t-6주      t-6주
# Baltic Supramax index (BSI)2005.01.01               [선행시점없음]  [선행시점없음]
# Baltic Handysize Index (BHSI)2006.05.23             [선행시점없음]  [선행시점없음]
# SSY/Pacific Capesize Index1997.1.6=4114                t-22주     t-22주
# SSY/Atlantic Capesize Index1997.1.6=5000               t-24주     t-24주
# Howe Robinson Container Index1997.1.15=1000             t-0주      t-0주
# China Containerized Freight Index (CCFI)1998.1....      t-0주      t-0주
# Shanghai Containerized Freight Index (SCFI)2009...  [선행시점없음]  [선행시점없음]
# China Coastal Bulk Freight Index (CBFI)2000.1.1...     t-17주     t-17주
# China Newbuilding Price Index (CNPI)2011.07.01=...      t-0주      t-0주
# China Bulker Newbuilding Price Index (CNDPI)201...      t-0주      t-0주
# China Tanker Newbuilding Price Index (CNTPI)201...      t-0주      t-0주
# China Container Newbuilding Price Index (CNCPI)...      t-0주      t-0주
# year                                                    t-0주      t-0주
# month                                                  t-19주     t-19주
# day                                                    t-20주     t-20주

# %% [markdown]
# # 시발 그냥 코사인유사도나 피어슨상관계수나 선행시점 결과는 똑같았다 시간아깝네

# %%
a=cos_total.describe()
a.ix['max'][a.ix['max']>0.6]
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# GSCI Industrial Metals1970=100                                  0.636264
# GSCI Precious Metals1970=100                                    0.730985
# GSCI Softs1970=100                                              0.673708
# Reuters Index of Commodity Prices1931.09.18=100                 0.695277
# CRB BLS Spot Index1967=100                                      0.715209
# PDS 귀금속 하위지수2015.01.02=100                                      0.695138
# PDS 비철금속 하위지수2015.01.02=100                                     0.642404
# PDS 철강 하위지수2015.01.02=100                                       0.725773
# LMEX Index1999.04=1000                                          0.645227
# Rogers International Commodities Index Metals1998.07.31=1000    0.701138
# USD/RMB (미국 달러 / 중국 인민폐)                                        0.652718
# Baltic Panamax Index (BPI)1998.05.06                            0.630368
# China Coastal Bulk Freight Index (CBFI)2000.1.1=1000            0.607675
# year                                                            0.609456
# Name: max, dtype: float64

# %%
b=corr_t.describe()
b.ix['max'][b.ix['max']>0.7]
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Bloomberg(DJ-UBS) Commodity Index1991=100                            0.881856
# Bloomberg Commodity Total Return1991=100                             0.883724
# TR/CC CRB Index1967=100                                              0.868078
# S&P GSCI1970=100                                                     0.841933
# GSCI Energy1970=100                                                  0.860540
# GSCI Petroleum1970=100                                               0.859338
# GSCI Non-Energy1970=100                                              0.906347
# GSCI Reduced Energy Index (CPW 2)1970=100                            0.902240
# GSCI Light Energy Index (CPW 4)1970=100                              0.913919
# GSCI Industrial Metals1970=100                                       0.794776
# GSCI Precious Metals1970=100                                         0.811105
# GSCI Agriculture1970=100                                             0.916742
# GSCI Softs1970=100                                                   0.796076
# Reuters Index of Commodity Prices1931.09.18=100                      0.774382
# CRB BLS Spot Index1967=100                                           0.746634
# PDS 철강 하위지수2015.01.02=100                                            0.725773
# LMEX Index1999.04=1000                                               0.798178
# Rogers International Commodities Index1998.07.31=1000                0.865541
# Rogers International Commodities Index Energy1998.07.31=1000         0.785189
# Rogers International Commodities Index Metals1998.07.31=1000         0.848054
# Rogers International Commodities Index Agriculture1998.07.31=1000    0.835792
# Shanghai Containerized Freight Index (SCFI)2009.10.16=1000           0.706337
# China Coastal Bulk Freight Index (CBFI)2000.1.1=1000                 0.713829
# Name: max, dtype: float64

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

plt.xticks(rotation=30, fontsize = 13)
plt.yticks(fontsize = 14)
plt.xlabel('시점', fontsize=14)
plt.ylabel('유사도', fontsize=14, rotation = 0) 
plt.title('시점별 코사인 유사도', fontsize = 16)

ax.grid(True) # 얇은 선 격자
plt.plot(cos_total.iloc[:,1:])
plt.show()
