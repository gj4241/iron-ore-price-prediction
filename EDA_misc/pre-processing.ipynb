# %%
# %matplotlib inline
import os

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
krfont = {'family' : 'NanumGothic', 'weight' : 'bold', 'size'   : 10}
matplotlib.rc('font', **krfont)

# %%
data_list = os.listdir('data/lag')
data_list
# Out:
# ['iron-ore_vs_exchangeIndex.csv',
#  'iron-ore_vs_mainIndex_1.csv',
#  'iron-ore_vs_mainIndex_2.csv',
#  'iron-ore_vs_shipIndex.csv']

# %%
data_dir = 'data/lag'

price_index_1 = pd.read_csv(os.path.join(data_dir,data_list[1]),encoding='euc-kr')
price_index_2 = pd.read_csv(os.path.join(data_dir,data_list[2]),encoding='euc-kr')
price_ship = pd.read_csv(os.path.join(data_dir,data_list[3]),encoding='euc-kr')
price_exchange = pd.read_csv(os.path.join(data_dir,data_list[0]),encoding='euc-kr')

# %%
price_index_1.columns=['날짜', 'target',
       'Bloomberg(DJ-UBS) Commodity Index1991=100',
       'Bloomberg Commodity Total Return1991=100', 'TR/CC CRB Index1967=100',
       'S&P GSCI1970=100', 'GSCI Energy1970=100', 'GSCI Petroleum1970=100',
       'GSCI Non-Energy1970=100', 'GSCI Reduced Energy Index (CPW 2)1970=100',
       'GSCI Light Energy Index (CPW 4)1970=100',
       'GSCI Industrial Metals1970=100', 'GSCI Precious Metals1970=100',
       'GSCI Agriculture1970=100', 'GSCI Livestock1970=100',
       'GSCI Softs1970=100', 'Reuters Index of Commodity Prices1931.09.18=100',
       'CRB BLS Spot Index1967=100', 'PDS 원자재 지수2015.01.02=100',
       'PDS 귀금속 하위지수2015.01.02=100']

# %%
price_index_2.columns=['날짜', 'target',
       'PDS 에너지 하위지수2015.01.02=100', 'PDS 비철금속 하위지수2015.01.02=100',
       'PDS 철강 하위지수2015.01.02=100', 'PDS 석유화학 하위지수2015.01.02=100',
       'PDS 농산물 하위지수2015.01.02=100', 'LMEX Index1999.04=1000',
       'US Dollar IndexMar 1973=100',
       'DRAMeXchange Index (DXI)2001.10.01=1000', 'TOCOM Index2002.05.31=100',
       'Rogers International Commodities Index1998.07.31=1000',
       'Rogers International Commodities Index Energy1998.07.31=1000',
       'Rogers International Commodities Index Metals1998.07.31=1000',
       'Rogers International Commodities Index Agriculture1998.07.31=1000']

# %%
price_ship.columns=['날짜', 'target',
       'Baltic Dry Index (BDI)1985.01.04',
       'Baltic Capesize Index (BCI)1999.03.01',
       'Baltic Panamax Index (BPI)1998.05.06',
       'Baltic Clean Tanker Index (BCTI)1998.08.03',
       'Baltic Dirty Tanker Index (BDTI)1998.08.03',
       'Baltic Supramax index (BSI)2005.01.01',
       'Baltic Handysize Index (BHSI)2006.05.23',
       'SSY/Pacific Capesize Index1997.1.6=4114',
       'SSY/Atlantic Capesize Index1997.1.6=5000',
       'Howe Robinson Container Index1997.1.15=1000',
       'China Containerized Freight Index (CCFI)1998.1.1=1000',
       'Shanghai Containerized Freight Index (SCFI)2009.10.16=1000',
       'China Coastal Bulk Freight Index (CBFI)2000.1.1=1000',
       'China Newbuilding Price Index (CNPI)2011.07.01=1000',
       'China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000',
       'China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000',
       'China Container Newbuilding Price Index (CNCPI)2011.07.01=1000']

# %%
price_exchange.columns=['날짜', 'target',
       'USD/KRW (미국 달러 / 한국 원)', 'CNY/KRW (중국 인민폐 / 한국 원)',
       'USD/CNY (미국 달러 / 중국 인민폐)']

# %% [markdown]
# ## 시점에 따른 유사도 구하기

# %%
ship_index=price_ship[['날짜','Baltic Dry Index (BDI)1985.01.04',
       'Baltic Capesize Index (BCI)1999.03.01',
       'Baltic Panamax Index (BPI)1998.05.06',
       'Baltic Clean Tanker Index (BCTI)1998.08.03',
       'Baltic Dirty Tanker Index (BDTI)1998.08.03',
       'Baltic Supramax index (BSI)2005.01.01',
       'Baltic Handysize Index (BHSI)2006.05.23',
       'SSY/Pacific Capesize Index1997.1.6=4114',
       'SSY/Atlantic Capesize Index1997.1.6=5000',
       'Howe Robinson Container Index1997.1.15=1000',
       'China Containerized Freight Index (CCFI)1998.1.1=1000',
       'Shanghai Containerized Freight Index (SCFI)2009.10.16=1000',
       'China Coastal Bulk Freight Index (CBFI)2000.1.1=1000',
       'China Newbuilding Price Index (CNPI)2011.07.01=1000',
       'China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000',
       'China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000',
       'China Container Newbuilding Price Index (CNCPI)2011.07.01=1000']]

# %%
target=price_ship[:-1][['날짜','target']]
target.head()
# Out:
#          날짜  target
# 0  20180703   64.55
# 1  20180702   64.54
# 2  20180630   65.02
# 3  20180629   65.02
# 4  20180628   64.44

# %%
ship_t1=pd.merge(target,ship_index[1:],how='outer',on='날짜')
ship_t1=ship_t1.dropna()
ship_t1.head()
# Out:
#          날짜  target  Baltic Dry Index (BDI)1985.01.04  \
# 1  20180702   64.54                            1422.0
# 2  20180630   65.02                            1385.0
# 3  20180629   65.02                            1385.0
# 4  20180628   64.44                            1329.0
# 5  20180627   64.60                            1309.0
#
#    Baltic Capesize Index (BCI)1999.03.01  \
# 1                                 2304.0
# 2                                 2170.0
# 3                                 2170.0
# 4                                 2025.0
# 5                                 1942.0
#
#    Baltic Panamax Index (BPI)1998.05.06  \
# 1                                1338.0
# 2                                1336.0
# 3                                1336.0
# 4                                1331.0
# 5                                1324.0
#
#    Baltic Clean Tanker Index (BCTI)1998.08.03  \
# 1                                       500.0
# 2                                       496.0
# 3                                       496.0
# 4                                       493.0
# 5                                       496.0
#
#    Baltic Dirty Tanker Index (BDTI)1998.08.03  \
# 1                                       705.0
# 2                                       712.0
# 3                                       712.0
# 4                                       724.0
# 5                                       727.0
#
#    Baltic Supramax index (BSI)2005.01.01  \
# 1                                 1034.0
# 2                                 1042.0
# 3                                 1042.0
# 4                                 1055.0
# 5                                 1067.0
#
#    Baltic Handysize Index (BHSI)2006.05.23  \
# 1                                    575.0
# 2                                    581.0
# 3                                    581.0
# 4                                    583.0
# 5                                    585.0
#
#    SSY/Pacific Capesize Index1997.1.6=4114  \
# 1                                   4997.0
# 2                                   4977.0
# 3                                   4977.0
# 4                                   4977.0
# 5                                   4977.0
#
#    SSY/Atlantic Capesize Index1997.1.6=5000  \
# 1                                    8625.0
# 2                                    8038.0
# 3                                    8038.0
# 4                                    8038.0
# 5                                    8038.0
#
#    Howe Robinson Container Index1997.1.15=1000  \
# 1                                        842.0
# 2                                        842.0
# 3                                        842.0
# 4                                        842.0
# 5                                        842.0
#
#    China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 1                                             815.89
# 2                                             815.89
# 3                                             815.89
# 4                                             812.18
# 5                                             812.18
#
#    Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 1                                             821.18
# 2                                             821.18
# 3                                             821.18
# 4                                             751.13
# 5                                             751.13
#
#    China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 1                                            1105.50
# 2                                            1105.50
# 3                                            1105.50
# 4                                            1133.57
# 5                                            1133.57
#
#    China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 1                                              801.0
# 2                                              801.0
# 3                                              794.0
# 4                                              794.0
# 5                                              794.0
#
#    China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 1                                              828.0
# 2                                              828.0
# 3                                              824.0
# 4                                              824.0
# 5                                              824.0
#
#    China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 1                                              855.0
# 2                                              855.0
# 3                                              849.0
# 4                                              849.0
# 5                                              849.0
#
#    China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# 1                                              821.0
# 2                                              821.0
# 3                                              810.0
# 4                                              810.0
# 5                                              810.0

# %%
ship_t1.corr()
# Out:
#                                                           날짜    target  \
# 날짜                                                  1.000000 -0.522636
# target                                             -0.522636  1.000000
# Baltic Dry Index (BDI)1985.01.04                   -0.116637  0.676828
# Baltic Capesize Index (BCI)1999.03.01              -0.124810  0.544211
# Baltic Panamax Index (BPI)1998.05.06                0.113923  0.567728
# Baltic Clean Tanker Index (BCTI)1998.08.03         -0.097532  0.002284
# Baltic Dirty Tanker Index (BDTI)1998.08.03         -0.095749 -0.031310
# Baltic Supramax index (BSI)2005.01.01              -0.181190  0.718575
# Baltic Handysize Index (BHSI)2006.05.23            -0.015115  0.675930
# SSY/Pacific Capesize Index1997.1.6=4114            -0.341881  0.769670
# SSY/Atlantic Capesize Index1997.1.6=5000           -0.097747  0.609087
# Howe Robinson Container Index1997.1.15=1000         0.261117 -0.162620
# China Containerized Freight Index (CCFI)1998.1.... -0.701359  0.683665
# Shanghai Containerized Freight Index (SCFI)2009... -0.459260  0.696305
# China Coastal Bulk Freight Index (CBFI)2000.1.1...  0.302304  0.439417
# China Newbuilding Price Index (CNPI)2011.07.01=... -0.896589  0.394541
# China Bulker Newbuilding Price Index (CNDPI)201... -0.842287  0.479296
# China Tanker Newbuilding Price Index (CNTPI)201... -0.865420  0.189348
# China Container Newbuilding Price Index (CNCPI)... -0.835663  0.119158
#
#                                                     Baltic Dry Index (BDI)1985.01.04  \
# 날짜                                                                         -0.116637
# target                                                                      0.676828
# Baltic Dry Index (BDI)1985.01.04                                            1.000000
# Baltic Capesize Index (BCI)1999.03.01                                       0.927974
# Baltic Panamax Index (BPI)1998.05.06                                        0.906553
# Baltic Clean Tanker Index (BCTI)1998.08.03                                  0.079716
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                 -0.097378
# Baltic Supramax index (BSI)2005.01.01                                       0.899146
# Baltic Handysize Index (BHSI)2006.05.23                                     0.885646
# SSY/Pacific Capesize Index1997.1.6=4114                                     0.915717
# SSY/Atlantic Capesize Index1997.1.6=5000                                    0.943189
# Howe Robinson Container Index1997.1.15=1000                                 0.171087
# China Containerized Freight Index (CCFI)1998.1....                          0.324936
# Shanghai Containerized Freight Index (SCFI)2009...                          0.411712
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                          0.704216
# China Newbuilding Price Index (CNPI)2011.07.01=...                         -0.015367
# China Bulker Newbuilding Price Index (CNDPI)201...                          0.107886
# China Tanker Newbuilding Price Index (CNTPI)201...                         -0.212562
# China Container Newbuilding Price Index (CNCPI)...                         -0.267454
#
#                                                     Baltic Capesize Index (BCI)1999.03.01  \
# 날짜                                                                              -0.124810
# target                                                                           0.544211
# Baltic Dry Index (BDI)1985.01.04                                                 0.927974
# Baltic Capesize Index (BCI)1999.03.01                                            1.000000
# Baltic Panamax Index (BPI)1998.05.06                                             0.756437
# Baltic Clean Tanker Index (BCTI)1998.08.03                                       0.039157
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                      -0.095697
# Baltic Supramax index (BSI)2005.01.01                                            0.737468
# Baltic Handysize Index (BHSI)2006.05.23                                          0.727225
# SSY/Pacific Capesize Index1997.1.6=4114                                          0.882679
# SSY/Atlantic Capesize Index1997.1.6=5000                                         0.934914
# Howe Robinson Container Index1997.1.15=1000                                      0.090021
# China Containerized Freight Index (CCFI)1998.1....                               0.248015
# Shanghai Containerized Freight Index (SCFI)2009...                               0.333266
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                               0.639708
# China Newbuilding Price Index (CNPI)2011.07.01=...                              -0.022978
# China Bulker Newbuilding Price Index (CNDPI)201...                               0.076055
# China Tanker Newbuilding Price Index (CNTPI)201...                              -0.188617
# China Container Newbuilding Price Index (CNCPI)...                              -0.234170
#
#                                                     Baltic Panamax Index (BPI)1998.05.06  \
# 날짜                                                                              0.113923
# target                                                                          0.567728
# Baltic Dry Index (BDI)1985.01.04                                                0.906553
# Baltic Capesize Index (BCI)1999.03.01                                           0.756437
# Baltic Panamax Index (BPI)1998.05.06                                            1.000000
# Baltic Clean Tanker Index (BCTI)1998.08.03                                      0.088371
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                     -0.073111
# Baltic Supramax index (BSI)2005.01.01                                           0.851610
# Baltic Handysize Index (BHSI)2006.05.23                                         0.878442
# SSY/Pacific Capesize Index1997.1.6=4114                                         0.755707
# SSY/Atlantic Capesize Index1997.1.6=5000                                        0.809684
# Howe Robinson Container Index1997.1.15=1000                                     0.226584
# China Containerized Freight Index (CCFI)1998.1....                              0.165439
# Shanghai Containerized Freight Index (SCFI)2009...                              0.301025
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                              0.753888
# China Newbuilding Price Index (CNPI)2011.07.01=...                             -0.234090
# China Bulker Newbuilding Price Index (CNDPI)201...                             -0.105965
# China Tanker Newbuilding Price Index (CNTPI)201...                             -0.415990
# China Container Newbuilding Price Index (CNCPI)...                             -0.464767
#
#                                                     Baltic Clean Tanker Index (BCTI)1998.08.03  \
# 날짜                                                                                   -0.097532
# target                                                                                0.002284
# Baltic Dry Index (BDI)1985.01.04                                                      0.079716
# Baltic Capesize Index (BCI)1999.03.01                                                 0.039157
# Baltic Panamax Index (BPI)1998.05.06                                                  0.088371
# Baltic Clean Tanker Index (BCTI)1998.08.03                                            1.000000
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                            0.507422
# Baltic Supramax index (BSI)2005.01.01                                                 0.101095
# Baltic Handysize Index (BHSI)2006.05.23                                               0.067098
# SSY/Pacific Capesize Index1997.1.6=4114                                               0.067845
# SSY/Atlantic Capesize Index1997.1.6=5000                                              0.064044
# Howe Robinson Container Index1997.1.15=1000                                           0.335493
# China Containerized Freight Index (CCFI)1998.1....                                    0.300226
# Shanghai Containerized Freight Index (SCFI)2009...                                    0.198708
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                    0.045823
# China Newbuilding Price Index (CNPI)2011.07.01=...                                    0.247077
# China Bulker Newbuilding Price Index (CNDPI)201...                                    0.261370
# China Tanker Newbuilding Price Index (CNTPI)201...                                    0.229041
# China Container Newbuilding Price Index (CNCPI)...                                    0.231090
#
#                                                     Baltic Dirty Tanker Index (BDTI)1998.08.03  \
# 날짜                                                                                   -0.095749
# target                                                                               -0.031310
# Baltic Dry Index (BDI)1985.01.04                                                     -0.097378
# Baltic Capesize Index (BCI)1999.03.01                                                -0.095697
# Baltic Panamax Index (BPI)1998.05.06                                                 -0.073111
# Baltic Clean Tanker Index (BCTI)1998.08.03                                            0.507422
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                            1.000000
# Baltic Supramax index (BSI)2005.01.01                                                -0.121977
# Baltic Handysize Index (BHSI)2006.05.23                                              -0.084400
# SSY/Pacific Capesize Index1997.1.6=4114                                              -0.086291
# SSY/Atlantic Capesize Index1997.1.6=5000                                             -0.084884
# Howe Robinson Container Index1997.1.15=1000                                          -0.044855
# China Containerized Freight Index (CCFI)1998.1....                                    0.112884
# Shanghai Containerized Freight Index (SCFI)2009...                                    0.086784
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                   -0.074391
# China Newbuilding Price Index (CNPI)2011.07.01=...                                    0.143194
# China Bulker Newbuilding Price Index (CNDPI)201...                                    0.113757
# China Tanker Newbuilding Price Index (CNTPI)201...                                    0.174690
# China Container Newbuilding Price Index (CNCPI)...                                    0.186570
#
#                                                     Baltic Supramax index (BSI)2005.01.01  \
# 날짜                                                                              -0.181190
# target                                                                           0.718575
# Baltic Dry Index (BDI)1985.01.04                                                 0.899146
# Baltic Capesize Index (BCI)1999.03.01                                            0.737468
# Baltic Panamax Index (BPI)1998.05.06                                             0.851610
# Baltic Clean Tanker Index (BCTI)1998.08.03                                       0.101095
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                      -0.121977
# Baltic Supramax index (BSI)2005.01.01                                            1.000000
# Baltic Handysize Index (BHSI)2006.05.23                                          0.939982
# SSY/Pacific Capesize Index1997.1.6=4114                                          0.836206
# SSY/Atlantic Capesize Index1997.1.6=5000                                         0.802512
# Howe Robinson Container Index1997.1.15=1000                                      0.246130
# China Containerized Freight Index (CCFI)1998.1....                               0.426608
# Shanghai Containerized Freight Index (SCFI)2009...                               0.494484
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                               0.620034
# China Newbuilding Price Index (CNPI)2011.07.01=...                               0.118125
# China Bulker Newbuilding Price Index (CNDPI)201...                               0.251142
# China Tanker Newbuilding Price Index (CNTPI)201...                              -0.088496
# China Container Newbuilding Price Index (CNCPI)...                              -0.151019
#
#                                                     Baltic Handysize Index (BHSI)2006.05.23  \
# 날짜                                                                                -0.015115
# target                                                                             0.675930
# Baltic Dry Index (BDI)1985.01.04                                                   0.885646
# Baltic Capesize Index (BCI)1999.03.01                                              0.727225
# Baltic Panamax Index (BPI)1998.05.06                                               0.878442
# Baltic Clean Tanker Index (BCTI)1998.08.03                                         0.067098
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                        -0.084400
# Baltic Supramax index (BSI)2005.01.01                                              0.939982
# Baltic Handysize Index (BHSI)2006.05.23                                            1.000000
# SSY/Pacific Capesize Index1997.1.6=4114                                            0.792015
# SSY/Atlantic Capesize Index1997.1.6=5000                                           0.791965
# Howe Robinson Container Index1997.1.15=1000                                        0.198428
# China Containerized Freight Index (CCFI)1998.1....                                 0.330276
# Shanghai Containerized Freight Index (SCFI)2009...                                 0.451301
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                 0.751416
# China Newbuilding Price Index (CNPI)2011.07.01=...                                -0.054098
# China Bulker Newbuilding Price Index (CNDPI)201...                                 0.093818
# China Tanker Newbuilding Price Index (CNTPI)201...                                -0.266896
# China Container Newbuilding Price Index (CNCPI)...                                -0.339476
#
#                                                     SSY/Pacific Capesize Index1997.1.6=4114  \
# 날짜                                                                                -0.341881
# target                                                                             0.769670
# Baltic Dry Index (BDI)1985.01.04                                                   0.915717
# Baltic Capesize Index (BCI)1999.03.01                                              0.882679
# Baltic Panamax Index (BPI)1998.05.06                                               0.755707
# Baltic Clean Tanker Index (BCTI)1998.08.03                                         0.067845
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                        -0.086291
# Baltic Supramax index (BSI)2005.01.01                                              0.836206
# Baltic Handysize Index (BHSI)2006.05.23                                            0.792015
# SSY/Pacific Capesize Index1997.1.6=4114                                            1.000000
# SSY/Atlantic Capesize Index1997.1.6=5000                                           0.934945
# Howe Robinson Container Index1997.1.15=1000                                        0.099969
# China Containerized Freight Index (CCFI)1998.1....                                 0.535184
# Shanghai Containerized Freight Index (SCFI)2009...                                 0.565775
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                 0.601593
# China Newbuilding Price Index (CNPI)2011.07.01=...                                 0.237472
# China Bulker Newbuilding Price Index (CNDPI)201...                                 0.356734
# China Tanker Newbuilding Price Index (CNTPI)201...                                 0.022058
# China Container Newbuilding Price Index (CNCPI)...                                -0.038776
#
#                                                     SSY/Atlantic Capesize Index1997.1.6=5000  \
# 날짜                                                                                 -0.097747
# target                                                                              0.609087
# Baltic Dry Index (BDI)1985.01.04                                                    0.943189
# Baltic Capesize Index (BCI)1999.03.01                                               0.934914
# Baltic Panamax Index (BPI)1998.05.06                                                0.809684
# Baltic Clean Tanker Index (BCTI)1998.08.03                                          0.064044
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                         -0.084884
# Baltic Supramax index (BSI)2005.01.01                                               0.802512
# Baltic Handysize Index (BHSI)2006.05.23                                             0.791965
# SSY/Pacific Capesize Index1997.1.6=4114                                             0.934945
# SSY/Atlantic Capesize Index1997.1.6=5000                                            1.000000
# Howe Robinson Container Index1997.1.15=1000                                         0.185051
# China Containerized Freight Index (CCFI)1998.1....                                  0.318841
# Shanghai Containerized Freight Index (SCFI)2009...                                  0.410743
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                  0.677547
# China Newbuilding Price Index (CNPI)2011.07.01=...                                  0.001316
# China Bulker Newbuilding Price Index (CNDPI)201...                                  0.124508
# China Tanker Newbuilding Price Index (CNTPI)201...                                 -0.190060
# China Container Newbuilding Price Index (CNCPI)...                                 -0.236292
#
#                                                     Howe Robinson Container Index1997.1.15=1000  \
# 날짜                                                                                     0.261117
# target                                                                                -0.162620
# Baltic Dry Index (BDI)1985.01.04                                                       0.171087
# Baltic Capesize Index (BCI)1999.03.01                                                  0.090021
# Baltic Panamax Index (BPI)1998.05.06                                                   0.226584
# Baltic Clean Tanker Index (BCTI)1998.08.03                                             0.335493
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                            -0.044855
# Baltic Supramax index (BSI)2005.01.01                                                  0.246130
# Baltic Handysize Index (BHSI)2006.05.23                                                0.198428
# SSY/Pacific Capesize Index1997.1.6=4114                                                0.099969
# SSY/Atlantic Capesize Index1997.1.6=5000                                               0.185051
# Howe Robinson Container Index1997.1.15=1000                                            1.000000
# China Containerized Freight Index (CCFI)1998.1....                                     0.055972
# Shanghai Containerized Freight Index (SCFI)2009...                                    -0.051754
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                     0.143056
# China Newbuilding Price Index (CNPI)2011.07.01=...                                     0.006366
# China Bulker Newbuilding Price Index (CNDPI)201...                                     0.098750
# China Tanker Newbuilding Price Index (CNTPI)201...                                    -0.027460
# China Container Newbuilding Price Index (CNCPI)...                                    -0.017050
#
#                                                     China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 날짜                                                                                          -0.701359
# target                                                                                       0.683665
# Baltic Dry Index (BDI)1985.01.04                                                             0.324936
# Baltic Capesize Index (BCI)1999.03.01                                                        0.248015
# Baltic Panamax Index (BPI)1998.05.06                                                         0.165439
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.300226
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.112884
# Baltic Supramax index (BSI)2005.01.01                                                        0.426608
# Baltic Handysize Index (BHSI)2006.05.23                                                      0.330276
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.535184
# SSY/Atlantic Capesize Index1997.1.6=5000                                                     0.318841
# Howe Robinson Container Index1997.1.15=1000                                                  0.055972
# China Containerized Freight Index (CCFI)1998.1....                                           1.000000
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.848821
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                           0.064259
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           0.783780
# China Bulker Newbuilding Price Index (CNDPI)201...                                           0.853481
# China Tanker Newbuilding Price Index (CNTPI)201...                                           0.605451
# China Container Newbuilding Price Index (CNCPI)...                                           0.550220
#
#                                                     Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 날짜                                                                                          -0.459260
# target                                                                                       0.696305
# Baltic Dry Index (BDI)1985.01.04                                                             0.411712
# Baltic Capesize Index (BCI)1999.03.01                                                        0.333266
# Baltic Panamax Index (BPI)1998.05.06                                                         0.301025
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.198708
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.086784
# Baltic Supramax index (BSI)2005.01.01                                                        0.494484
# Baltic Handysize Index (BHSI)2006.05.23                                                      0.451301
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.565775
# SSY/Atlantic Capesize Index1997.1.6=5000                                                     0.410743
# Howe Robinson Container Index1997.1.15=1000                                                 -0.051754
# China Containerized Freight Index (CCFI)1998.1....                                           0.848821
# Shanghai Containerized Freight Index (SCFI)2009...                                           1.000000
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                           0.271281
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           0.504436
# China Bulker Newbuilding Price Index (CNDPI)201...                                           0.603426
# China Tanker Newbuilding Price Index (CNTPI)201...                                           0.290199
# China Container Newbuilding Price Index (CNCPI)...                                           0.225594
#
#                                                     China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 날짜                                                                                           0.302304
# target                                                                                       0.439417
# Baltic Dry Index (BDI)1985.01.04                                                             0.704216
# Baltic Capesize Index (BCI)1999.03.01                                                        0.639708
# Baltic Panamax Index (BPI)1998.05.06                                                         0.753888
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.045823
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                  -0.074391
# Baltic Supramax index (BSI)2005.01.01                                                        0.620034
# Baltic Handysize Index (BHSI)2006.05.23                                                      0.751416
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.601593
# SSY/Atlantic Capesize Index1997.1.6=5000                                                     0.677547
# Howe Robinson Container Index1997.1.15=1000                                                  0.143056
# China Containerized Freight Index (CCFI)1998.1....                                           0.064259
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.271281
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                           1.000000
# China Newbuilding Price Index (CNPI)2011.07.01=...                                          -0.366740
# China Bulker Newbuilding Price Index (CNDPI)201...                                          -0.222976
# China Tanker Newbuilding Price Index (CNTPI)201...                                          -0.546696
# China Container Newbuilding Price Index (CNCPI)...                                          -0.606564
#
#                                                     China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 날짜                                                                                          -0.896589
# target                                                                                       0.394541
# Baltic Dry Index (BDI)1985.01.04                                                            -0.015367
# Baltic Capesize Index (BCI)1999.03.01                                                       -0.022978
# Baltic Panamax Index (BPI)1998.05.06                                                        -0.234090
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.247077
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.143194
# Baltic Supramax index (BSI)2005.01.01                                                        0.118125
# Baltic Handysize Index (BHSI)2006.05.23                                                     -0.054098
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.237472
# SSY/Atlantic Capesize Index1997.1.6=5000                                                     0.001316
# Howe Robinson Container Index1997.1.15=1000                                                  0.006366
# China Containerized Freight Index (CCFI)1998.1....                                           0.783780
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.504436
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                          -0.366740
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           1.000000
# China Bulker Newbuilding Price Index (CNDPI)201...                                           0.979461
# China Tanker Newbuilding Price Index (CNTPI)201...                                           0.960985
# China Container Newbuilding Price Index (CNCPI)...                                           0.934614
#
#                                                     China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 날짜                                                                                          -0.842287
# target                                                                                       0.479296
# Baltic Dry Index (BDI)1985.01.04                                                             0.107886
# Baltic Capesize Index (BCI)1999.03.01                                                        0.076055
# Baltic Panamax Index (BPI)1998.05.06                                                        -0.105965
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.261370
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.113757
# Baltic Supramax index (BSI)2005.01.01                                                        0.251142
# Baltic Handysize Index (BHSI)2006.05.23                                                      0.093818
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.356734
# SSY/Atlantic Capesize Index1997.1.6=5000                                                     0.124508
# Howe Robinson Container Index1997.1.15=1000                                                  0.098750
# China Containerized Freight Index (CCFI)1998.1....                                           0.853481
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.603426
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                          -0.222976
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           0.979461
# China Bulker Newbuilding Price Index (CNDPI)201...                                           1.000000
# China Tanker Newbuilding Price Index (CNTPI)201...                                           0.892512
# China Container Newbuilding Price Index (CNCPI)...                                           0.853472
#
#                                                     China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 날짜                                                                                          -0.865420
# target                                                                                       0.189348
# Baltic Dry Index (BDI)1985.01.04                                                            -0.212562
# Baltic Capesize Index (BCI)1999.03.01                                                       -0.188617
# Baltic Panamax Index (BPI)1998.05.06                                                        -0.415990
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.229041
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.174690
# Baltic Supramax index (BSI)2005.01.01                                                       -0.088496
# Baltic Handysize Index (BHSI)2006.05.23                                                     -0.266896
# SSY/Pacific Capesize Index1997.1.6=4114                                                      0.022058
# SSY/Atlantic Capesize Index1997.1.6=5000                                                    -0.190060
# Howe Robinson Container Index1997.1.15=1000                                                 -0.027460
# China Containerized Freight Index (CCFI)1998.1....                                           0.605451
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.290199
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                          -0.546696
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           0.960985
# China Bulker Newbuilding Price Index (CNDPI)201...                                           0.892512
# China Tanker Newbuilding Price Index (CNTPI)201...                                           1.000000
# China Container Newbuilding Price Index (CNCPI)...                                           0.992552
#
#                                                     China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# 날짜                                                                                          -0.835663
# target                                                                                       0.119158
# Baltic Dry Index (BDI)1985.01.04                                                            -0.267454
# Baltic Capesize Index (BCI)1999.03.01                                                       -0.234170
# Baltic Panamax Index (BPI)1998.05.06                                                        -0.464767
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                   0.231090
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                   0.186570
# Baltic Supramax index (BSI)2005.01.01                                                       -0.151019
# Baltic Handysize Index (BHSI)2006.05.23                                                     -0.339476
# SSY/Pacific Capesize Index1997.1.6=4114                                                     -0.038776
# SSY/Atlantic Capesize Index1997.1.6=5000                                                    -0.236292
# Howe Robinson Container Index1997.1.15=1000                                                 -0.017050
# China Containerized Freight Index (CCFI)1998.1....                                           0.550220
# Shanghai Containerized Freight Index (SCFI)2009...                                           0.225594
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                          -0.606564
# China Newbuilding Price Index (CNPI)2011.07.01=...                                           0.934614
# China Bulker Newbuilding Price Index (CNDPI)201...                                           0.853472
# China Tanker Newbuilding Price Index (CNTPI)201...                                           0.992552
# China Container Newbuilding Price Index (CNCPI)...                                           1.000000

# %%
ship_t1.cov()
# Out:
#                                                               날짜  \
# 날짜                                                  2.035792e+08
# target                                             -1.814450e+05
# Baltic Dry Index (BDI)1985.01.04                   -6.568835e+05
# Baltic Capesize Index (BCI)1999.03.01              -1.685281e+06
# Baltic Panamax Index (BPI)1998.05.06                6.478391e+05
# Baltic Clean Tanker Index (BCTI)1998.08.03         -1.339610e+05
# Baltic Dirty Tanker Index (BDTI)1998.08.03         -1.677725e+05
# Baltic Supramax index (BSI)2005.01.01              -6.177344e+05
# Baltic Handysize Index (BHSI)2006.05.23            -2.891638e+04
# SSY/Pacific Capesize Index1997.1.6=4114            -8.229872e+06
# SSY/Atlantic Capesize Index1997.1.6=5000           -2.831657e+06
# Howe Robinson Container Index1997.1.15=1000         4.126185e+05
# China Containerized Freight Index (CCFI)1998.1.... -1.501604e+06
# Shanghai Containerized Freight Index (SCFI)2009... -1.269920e+06
# China Coastal Bulk Freight Index (CBFI)2000.1.1...  7.155844e+05
# China Newbuilding Price Index (CNPI)2011.07.01=... -9.287116e+05
# China Bulker Newbuilding Price Index (CNDPI)201... -9.286209e+05
# China Tanker Newbuilding Price Index (CNTPI)201... -8.651986e+05
# China Container Newbuilding Price Index (CNCPI)... -5.300746e+05
#
#                                                            target  \
# 날짜                                                 -181445.005693
# target                                                 592.048330
# Baltic Dry Index (BDI)1985.01.04                      6500.414892
# Baltic Capesize Index (BCI)1999.03.01                12531.433939
# Baltic Panamax Index (BPI)1998.05.06                  5505.650190
# Baltic Clean Tanker Index (BCTI)1998.08.03               5.350935
# Baltic Dirty Tanker Index (BDTI)1998.08.03             -93.557271
# Baltic Supramax index (BSI)2005.01.01                 4177.830056
# Baltic Handysize Index (BHSI)2006.05.23               2205.151237
# SSY/Pacific Capesize Index1997.1.6=4114              31596.153337
# SSY/Atlantic Capesize Index1997.1.6=5000             30090.531805
# Howe Robinson Container Index1997.1.15=1000           -438.226429
# China Containerized Freight Index (CCFI)1998.1....    2496.145587
# Shanghai Containerized Freight Index (SCFI)2009...    3283.436506
# China Coastal Bulk Freight Index (CBFI)2000.1.1...    1773.802782
# China Newbuilding Price Index (CNPI)2011.07.01=...     696.933837
# China Bulker Newbuilding Price Index (CNDPI)201...     901.143862
# China Tanker Newbuilding Price Index (CNTPI)201...     322.821233
# China Container Newbuilding Price Index (CNCPI)...     128.896541
#
#                                                     Baltic Dry Index (BDI)1985.01.04  \
# 날짜                                                                    -656883.455577
# target                                                                   6500.414892
# Baltic Dry Index (BDI)1985.01.04                                       155800.375336
# Baltic Capesize Index (BCI)1999.03.01                                  346637.153852
# Baltic Panamax Index (BPI)1998.05.06                                   142615.725520
# Baltic Clean Tanker Index (BCTI)1998.08.03                               3028.968827
# Baltic Dirty Tanker Index (BDTI)1998.08.03                              -4720.261886
# Baltic Supramax index (BSI)2005.01.01                                   84803.684250
# Baltic Handysize Index (BHSI)2006.05.23                                 46870.783046
# SSY/Pacific Capesize Index1997.1.6=4114                                609813.049962
# SSY/Atlantic Capesize Index1997.1.6=5000                               755883.567514
# Howe Robinson Container Index1997.1.15=1000                              7479.086737
# China Containerized Freight Index (CCFI)1998.1....                      19245.529502
# Shanghai Containerized Freight Index (SCFI)2009...                      31494.034169
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                      46114.728031
# China Newbuilding Price Index (CNPI)2011.07.01=...                       -440.334462
# China Bulker Newbuilding Price Index (CNDPI)201...                       3290.482153
# China Tanker Newbuilding Price Index (CNTPI)201...                      -5878.854171
# China Container Newbuilding Price Index (CNCPI)...                      -4693.245774
#
#                                                     Baltic Capesize Index (BCI)1999.03.01  \
# 날짜                                                                          -1.685281e+06
# target                                                                       1.253143e+04
# Baltic Dry Index (BDI)1985.01.04                                             3.466372e+05
# Baltic Capesize Index (BCI)1999.03.01                                        8.955924e+05
# Baltic Panamax Index (BPI)1998.05.06                                         2.853103e+05
# Baltic Clean Tanker Index (BCTI)1998.08.03                                   3.567207e+03
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                  -1.112172e+04
# Baltic Supramax index (BSI)2005.01.01                                        1.667625e+05
# Baltic Handysize Index (BHSI)2006.05.23                                      9.227457e+04
# SSY/Pacific Capesize Index1997.1.6=4114                                      1.409319e+06
# SSY/Atlantic Capesize Index1997.1.6=5000                                     1.796382e+06
# Howe Robinson Container Index1997.1.15=1000                                  9.435035e+03
# China Containerized Freight Index (CCFI)1998.1....                           3.521931e+04
# Shanghai Containerized Freight Index (SCFI)2009...                           6.112197e+04
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                           1.004353e+05
# China Newbuilding Price Index (CNPI)2011.07.01=...                          -1.578661e+03
# China Bulker Newbuilding Price Index (CNDPI)201...                           5.561568e+03
# China Tanker Newbuilding Price Index (CNTPI)201...                          -1.250713e+04
# China Container Newbuilding Price Index (CNCPI)...                          -9.852049e+03
#
#                                                     Baltic Panamax Index (BPI)1998.05.06  \
# 날짜                                                                         647839.103225
# target                                                                       5505.650190
# Baltic Dry Index (BDI)1985.01.04                                           142615.725520
# Baltic Capesize Index (BCI)1999.03.01                                      285310.328397
# Baltic Panamax Index (BPI)1998.05.06                                       158847.164066
# Baltic Clean Tanker Index (BCTI)1998.08.03                                   3390.505299
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                  -3578.441868
# Baltic Supramax index (BSI)2005.01.01                                       81101.837463
# Baltic Handysize Index (BHSI)2006.05.23                                     46941.882488
# SSY/Pacific Capesize Index1997.1.6=4114                                    508152.801806
# SSY/Atlantic Capesize Index1997.1.6=5000                                   655204.987176
# Howe Robinson Container Index1997.1.15=1000                                 10001.501444
# China Containerized Freight Index (CCFI)1998.1....                           9894.105069
# Shanghai Containerized Freight Index (SCFI)2009...                          23251.094307
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                          49847.826815
# China Newbuilding Price Index (CNPI)2011.07.01=...                          -6773.205203
# China Bulker Newbuilding Price Index (CNDPI)201...                          -3263.339089
# China Tanker Newbuilding Price Index (CNTPI)201...                         -11617.025432
# China Container Newbuilding Price Index (CNCPI)...                          -8235.016432
#
#                                                     Baltic Clean Tanker Index (BCTI)1998.08.03  \
# 날짜                                                                              -133961.028029
# target                                                                                5.350935
# Baltic Dry Index (BDI)1985.01.04                                                   3028.968827
# Baltic Capesize Index (BCI)1999.03.01                                              3567.206554
# Baltic Panamax Index (BPI)1998.05.06                                               3390.505299
# Baltic Clean Tanker Index (BCTI)1998.08.03                                         9266.794656
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                         5998.647404
# Baltic Supramax index (BSI)2005.01.01                                              2325.377330
# Baltic Handysize Index (BHSI)2006.05.23                                             866.033505
# SSY/Pacific Capesize Index1997.1.6=4114                                           11018.804096
# SSY/Atlantic Capesize Index1997.1.6=5000                                          12517.363013
# Howe Robinson Container Index1997.1.15=1000                                        3576.802115
# China Containerized Freight Index (CCFI)1998.1....                                 4336.718049
# Shanghai Containerized Freight Index (SCFI)2009...                                 3707.078271
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                  731.806664
# China Newbuilding Price Index (CNPI)2011.07.01=...                                 1726.704189
# China Bulker Newbuilding Price Index (CNDPI)201...                                 1944.158063
# China Tanker Newbuilding Price Index (CNTPI)201...                                 1544.897230
# China Container Newbuilding Price Index (CNCPI)...                                  988.973139
#
#                                                     Baltic Dirty Tanker Index (BDTI)1998.08.03  \
# 날짜                                                                              -167772.500039
# target                                                                              -93.557271
# Baltic Dry Index (BDI)1985.01.04                                                  -4720.261886
# Baltic Capesize Index (BCI)1999.03.01                                            -11121.718436
# Baltic Panamax Index (BPI)1998.05.06                                              -3578.441868
# Baltic Clean Tanker Index (BCTI)1998.08.03                                         5998.647404
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                        15081.277403
# Baltic Supramax index (BSI)2005.01.01                                             -3579.283812
# Baltic Handysize Index (BHSI)2006.05.23                                           -1389.692755
# SSY/Pacific Capesize Index1997.1.6=4114                                          -17878.707716
# SSY/Atlantic Capesize Index1997.1.6=5000                                         -21164.950283
# Howe Robinson Container Index1997.1.15=1000                                        -610.068805
# China Containerized Freight Index (CCFI)1998.1....                                 2080.170036
# Shanghai Containerized Freight Index (SCFI)2009...                                 2065.416354
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                -1515.609322
# China Newbuilding Price Index (CNPI)2011.07.01=...                                 1276.632682
# China Bulker Newbuilding Price Index (CNDPI)201...                                 1079.467517
# China Tanker Newbuilding Price Index (CNTPI)201...                                 1503.172326
# China Container Newbuilding Price Index (CNCPI)...                                 1018.593846
#
#                                                     Baltic Supramax index (BSI)2005.01.01  \
# 날짜                                                                         -617734.425080
# target                                                                        4177.830056
# Baltic Dry Index (BDI)1985.01.04                                             84803.684250
# Baltic Capesize Index (BCI)1999.03.01                                       166762.544351
# Baltic Panamax Index (BPI)1998.05.06                                         81101.837463
# Baltic Clean Tanker Index (BCTI)1998.08.03                                    2325.377330
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                   -3579.283812
# Baltic Supramax index (BSI)2005.01.01                                        57095.315491
# Baltic Handysize Index (BHSI)2006.05.23                                      30114.638624
# SSY/Pacific Capesize Index1997.1.6=4114                                     337104.629300
# SSY/Atlantic Capesize Index1997.1.6=5000                                    389334.873756
# Howe Robinson Container Index1997.1.15=1000                                   6513.447832
# China Containerized Freight Index (CCFI)1998.1....                           15295.993047
# Shanghai Containerized Freight Index (SCFI)2009...                           22898.318191
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                           24579.059130
# China Newbuilding Price Index (CNPI)2011.07.01=...                            2049.098637
# China Bulker Newbuilding Price Index (CNDPI)201...                            4636.934565
# China Tanker Newbuilding Price Index (CNTPI)201...                           -1481.643999
# China Container Newbuilding Price Index (CNCPI)...                           -1604.242283
#
#                                                     Baltic Handysize Index (BHSI)2006.05.23  \
# 날짜                                                                            -28916.380458
# target                                                                          2205.151237
# Baltic Dry Index (BDI)1985.01.04                                               46870.783046
# Baltic Capesize Index (BCI)1999.03.01                                          92274.565471
# Baltic Panamax Index (BPI)1998.05.06                                           46941.882488
# Baltic Clean Tanker Index (BCTI)1998.08.03                                       866.033505
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                     -1389.692755
# Baltic Supramax index (BSI)2005.01.01                                          30114.638624
# Baltic Handysize Index (BHSI)2006.05.23                                        17976.931898
# SSY/Pacific Capesize Index1997.1.6=4114                                       179160.505277
# SSY/Atlantic Capesize Index1997.1.6=5000                                      215593.517534
# Howe Robinson Container Index1997.1.15=1000                                     2946.509495
# China Containerized Freight Index (CCFI)1998.1....                              6644.820747
# Shanghai Containerized Freight Index (SCFI)2009...                             11726.673866
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                             16714.276615
# China Newbuilding Price Index (CNPI)2011.07.01=...                              -526.578029
# China Bulker Newbuilding Price Index (CNDPI)201...                               971.980817
# China Tanker Newbuilding Price Index (CNTPI)201...                             -2507.391483
# China Container Newbuilding Price Index (CNCPI)...                             -2023.516261
#
#                                                     SSY/Pacific Capesize Index1997.1.6=4114  \
# 날짜                                                                            -8.229872e+06
# target                                                                         3.159615e+04
# Baltic Dry Index (BDI)1985.01.04                                               6.098130e+05
# Baltic Capesize Index (BCI)1999.03.01                                          1.409319e+06
# Baltic Panamax Index (BPI)1998.05.06                                           5.081528e+05
# Baltic Clean Tanker Index (BCTI)1998.08.03                                     1.101880e+04
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                    -1.787871e+04
# Baltic Supramax index (BSI)2005.01.01                                          3.371046e+05
# Baltic Handysize Index (BHSI)2006.05.23                                        1.791605e+05
# SSY/Pacific Capesize Index1997.1.6=4114                                        2.846444e+06
# SSY/Atlantic Capesize Index1997.1.6=5000                                       3.202648e+06
# Howe Robinson Container Index1997.1.15=1000                                    1.867933e+04
# China Containerized Freight Index (CCFI)1998.1....                             1.354884e+05
# Shanghai Containerized Freight Index (SCFI)2009...                             1.849889e+05
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                             1.683850e+05
# China Newbuilding Price Index (CNPI)2011.07.01=...                             2.908605e+04
# China Bulker Newbuilding Price Index (CNDPI)201...                             4.650584e+04
# China Tanker Newbuilding Price Index (CNTPI)201...                             2.607604e+03
# China Container Newbuilding Price Index (CNCPI)...                            -2.908375e+03
#
#                                                     SSY/Atlantic Capesize Index1997.1.6=5000  \
# 날짜                                                                             -2.831657e+06
# target                                                                          3.009053e+04
# Baltic Dry Index (BDI)1985.01.04                                                7.558836e+05
# Baltic Capesize Index (BCI)1999.03.01                                           1.796382e+06
# Baltic Panamax Index (BPI)1998.05.06                                            6.552050e+05
# Baltic Clean Tanker Index (BCTI)1998.08.03                                      1.251736e+04
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                     -2.116495e+04
# Baltic Supramax index (BSI)2005.01.01                                           3.893349e+05
# Baltic Handysize Index (BHSI)2006.05.23                                         2.155935e+05
# SSY/Pacific Capesize Index1997.1.6=4114                                         3.202648e+06
# SSY/Atlantic Capesize Index1997.1.6=5000                                        4.122337e+06
# Howe Robinson Container Index1997.1.15=1000                                     4.161103e+04
# China Containerized Freight Index (CCFI)1998.1....                              9.713919e+04
# Shanghai Containerized Freight Index (SCFI)2009...                              1.616191e+05
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                              2.282239e+05
# China Newbuilding Price Index (CNPI)2011.07.01=...                              1.940070e+02
# China Bulker Newbuilding Price Index (CNDPI)201...                              1.953349e+04
# China Tanker Newbuilding Price Index (CNTPI)201...                             -2.703860e+04
# China Container Newbuilding Price Index (CNCPI)...                             -2.132850e+04
#
#                                                     Howe Robinson Container Index1997.1.15=1000  \
# 날짜                                                                                412618.514886
# target                                                                              -438.226429
# Baltic Dry Index (BDI)1985.01.04                                                    7479.086737
# Baltic Capesize Index (BCI)1999.03.01                                               9435.034621
# Baltic Panamax Index (BPI)1998.05.06                                               10001.501444
# Baltic Clean Tanker Index (BCTI)1998.08.03                                          3576.802115
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                          -610.068805
# Baltic Supramax index (BSI)2005.01.01                                               6513.447832
# Baltic Handysize Index (BHSI)2006.05.23                                             2946.509495
# SSY/Pacific Capesize Index1997.1.6=4114                                            18679.332734
# SSY/Atlantic Capesize Index1997.1.6=5000                                           41611.031671
# Howe Robinson Container Index1997.1.15=1000                                        12265.716466
# China Containerized Freight Index (CCFI)1998.1....                                   930.180567
# Shanghai Containerized Freight Index (SCFI)2009...                                 -1110.811030
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                  2628.460061
# China Newbuilding Price Index (CNPI)2011.07.01=...                                    51.187753
# China Bulker Newbuilding Price Index (CNDPI)201...                                   845.077698
# China Tanker Newbuilding Price Index (CNTPI)201...                                  -213.089472
# China Container Newbuilding Price Index (CNCPI)...                                   -83.947554
#
#                                                     China Containerized Freight Index (CCFI)1998.1.1=1000  \
# 날짜                                                                                      -1.501604e+06
# target                                                                                   2.496146e+03
# Baltic Dry Index (BDI)1985.01.04                                                         1.924553e+04
# Baltic Capesize Index (BCI)1999.03.01                                                    3.521931e+04
# Baltic Panamax Index (BPI)1998.05.06                                                     9.894105e+03
# Baltic Clean Tanker Index (BCTI)1998.08.03                                               4.336718e+03
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                               2.080170e+03
# Baltic Supramax index (BSI)2005.01.01                                                    1.529599e+04
# Baltic Handysize Index (BHSI)2006.05.23                                                  6.644821e+03
# SSY/Pacific Capesize Index1997.1.6=4114                                                  1.354884e+05
# SSY/Atlantic Capesize Index1997.1.6=5000                                                 9.713919e+04
# Howe Robinson Container Index1997.1.15=1000                                              9.301806e+02
# China Containerized Freight Index (CCFI)1998.1....                                       2.251625e+04
# Shanghai Containerized Freight Index (SCFI)2009...                                       2.468396e+04
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       1.599670e+03
# China Newbuilding Price Index (CNPI)2011.07.01=...                                       8.538133e+03
# China Bulker Newbuilding Price Index (CNDPI)201...                                       9.895861e+03
# China Tanker Newbuilding Price Index (CNTPI)201...                                       6.365745e+03
# China Container Newbuilding Price Index (CNCPI)...                                       3.670490e+03
#
#                                                     Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# 날짜                                                                                      -1.269920e+06
# target                                                                                   3.283437e+03
# Baltic Dry Index (BDI)1985.01.04                                                         3.149403e+04
# Baltic Capesize Index (BCI)1999.03.01                                                    6.112197e+04
# Baltic Panamax Index (BPI)1998.05.06                                                     2.325109e+04
# Baltic Clean Tanker Index (BCTI)1998.08.03                                               3.707078e+03
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                               2.065416e+03
# Baltic Supramax index (BSI)2005.01.01                                                    2.289832e+04
# Baltic Handysize Index (BHSI)2006.05.23                                                  1.172667e+04
# SSY/Pacific Capesize Index1997.1.6=4114                                                  1.849889e+05
# SSY/Atlantic Capesize Index1997.1.6=5000                                                 1.616191e+05
# Howe Robinson Container Index1997.1.15=1000                                             -1.110811e+03
# China Containerized Freight Index (CCFI)1998.1....                                       2.468396e+04
# Shanghai Containerized Freight Index (SCFI)2009...                                       3.755792e+04
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       8.722065e+03
# China Newbuilding Price Index (CNPI)2011.07.01=...                                       7.097052e+03
# China Bulker Newbuilding Price Index (CNDPI)201...                                       9.036221e+03
# China Tanker Newbuilding Price Index (CNTPI)201...                                       3.940665e+03
# China Container Newbuilding Price Index (CNCPI)...                                       1.943651e+03
#
#                                                     China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# 날짜                                                                                      715584.359409
# target                                                                                    1773.802782
# Baltic Dry Index (BDI)1985.01.04                                                         46114.728031
# Baltic Capesize Index (BCI)1999.03.01                                                   100435.345644
# Baltic Panamax Index (BPI)1998.05.06                                                     49847.826815
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                 731.806664
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                               -1515.609322
# Baltic Supramax index (BSI)2005.01.01                                                    24579.059130
# Baltic Handysize Index (BHSI)2006.05.23                                                  16714.276615
# SSY/Pacific Capesize Index1997.1.6=4114                                                 168384.980327
# SSY/Atlantic Capesize Index1997.1.6=5000                                                228223.871563
# Howe Robinson Container Index1997.1.15=1000                                               2628.460061
# China Containerized Freight Index (CCFI)1998.1....                                        1599.669628
# Shanghai Containerized Freight Index (SCFI)2009...                                        8722.065414
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       27523.221597
# China Newbuilding Price Index (CNPI)2011.07.01=...                                       -4417.019422
# China Bulker Newbuilding Price Index (CNDPI)201...                                       -2858.376408
# China Tanker Newbuilding Price Index (CNTPI)201...                                       -6355.034441
# China Container Newbuilding Price Index (CNCPI)...                                       -4473.687763
#
#                                                     China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# 날짜                                                                                     -928711.588936
# target                                                                                     696.933837
# Baltic Dry Index (BDI)1985.01.04                                                          -440.334462
# Baltic Capesize Index (BCI)1999.03.01                                                    -1578.661117
# Baltic Panamax Index (BPI)1998.05.06                                                     -6773.205203
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                1726.704189
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                1276.632682
# Baltic Supramax index (BSI)2005.01.01                                                     2049.098637
# Baltic Handysize Index (BHSI)2006.05.23                                                   -526.578029
# SSY/Pacific Capesize Index1997.1.6=4114                                                  29086.047532
# SSY/Atlantic Capesize Index1997.1.6=5000                                                   194.006993
# Howe Robinson Container Index1997.1.15=1000                                                 51.187753
# China Containerized Freight Index (CCFI)1998.1....                                        8538.133281
# Shanghai Containerized Freight Index (SCFI)2009...                                        7097.051637
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       -4417.019422
# China Newbuilding Price Index (CNPI)2011.07.01=...                                        5270.376918
# China Bulker Newbuilding Price Index (CNDPI)201...                                        5494.391895
# China Tanker Newbuilding Price Index (CNTPI)201...                                        4888.319460
# China Container Newbuilding Price Index (CNCPI)...                                        3016.425256
#
#                                                     China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# 날짜                                                                                     -928620.946925
# target                                                                                     901.143862
# Baltic Dry Index (BDI)1985.01.04                                                          3290.482153
# Baltic Capesize Index (BCI)1999.03.01                                                     5561.567532
# Baltic Panamax Index (BPI)1998.05.06                                                     -3263.339089
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                1944.158063
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                1079.467517
# Baltic Supramax index (BSI)2005.01.01                                                     4636.934565
# Baltic Handysize Index (BHSI)2006.05.23                                                    971.980817
# SSY/Pacific Capesize Index1997.1.6=4114                                                  46505.841468
# SSY/Atlantic Capesize Index1997.1.6=5000                                                 19533.491683
# Howe Robinson Container Index1997.1.15=1000                                                845.077698
# China Containerized Freight Index (CCFI)1998.1....                                        9895.861046
# Shanghai Containerized Freight Index (SCFI)2009...                                        9036.220698
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       -2858.376408
# China Newbuilding Price Index (CNPI)2011.07.01=...                                        5494.391895
# China Bulker Newbuilding Price Index (CNDPI)201...                                        5970.677325
# China Tanker Newbuilding Price Index (CNTPI)201...                                        4832.236659
# China Container Newbuilding Price Index (CNCPI)...                                        2931.841798
#
#                                                     China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# 날짜                                                                                     -865198.556544
# target                                                                                     322.821233
# Baltic Dry Index (BDI)1985.01.04                                                         -5878.854171
# Baltic Capesize Index (BCI)1999.03.01                                                   -12507.128349
# Baltic Panamax Index (BPI)1998.05.06                                                    -11617.025432
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                1544.897230
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                1503.172326
# Baltic Supramax index (BSI)2005.01.01                                                    -1481.643999
# Baltic Handysize Index (BHSI)2006.05.23                                                  -2507.391483
# SSY/Pacific Capesize Index1997.1.6=4114                                                   2607.604224
# SSY/Atlantic Capesize Index1997.1.6=5000                                                -27038.598698
# Howe Robinson Container Index1997.1.15=1000                                               -213.089472
# China Containerized Freight Index (CCFI)1998.1....                                        6365.745112
# Shanghai Containerized Freight Index (SCFI)2009...                                        3940.664744
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       -6355.034441
# China Newbuilding Price Index (CNPI)2011.07.01=...                                        4888.319460
# China Bulker Newbuilding Price Index (CNDPI)201...                                        4832.236659
# China Tanker Newbuilding Price Index (CNTPI)201...                                        4909.578578
# China Container Newbuilding Price Index (CNCPI)...                                        3091.824165
#
#                                                     China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# 날짜                                                                                     -530074.610694
# target                                                                                     128.896541
# Baltic Dry Index (BDI)1985.01.04                                                         -4693.245774
# Baltic Capesize Index (BCI)1999.03.01                                                    -9852.049232
# Baltic Panamax Index (BPI)1998.05.06                                                     -8235.016432
# Baltic Clean Tanker Index (BCTI)1998.08.03                                                 988.973139
# Baltic Dirty Tanker Index (BDTI)1998.08.03                                                1018.593846
# Baltic Supramax index (BSI)2005.01.01                                                    -1604.242283
# Baltic Handysize Index (BHSI)2006.05.23                                                  -2023.516261
# SSY/Pacific Capesize Index1997.1.6=4114                                                  -2908.375401
# SSY/Atlantic Capesize Index1997.1.6=5000                                                -21328.495497
# Howe Robinson Container Index1997.1.15=1000                                                -83.947554
# China Containerized Freight Index (CCFI)1998.1....                                        3670.490103
# Shanghai Containerized Freight Index (SCFI)2009...                                        1943.651175
# China Coastal Bulk Freight Index (CBFI)2000.1.1...                                       -4473.687763
# China Newbuilding Price Index (CNPI)2011.07.01=...                                        3016.425256
# China Bulker Newbuilding Price Index (CNDPI)201...                                        2931.841798
# China Tanker Newbuilding Price Index (CNTPI)201...                                        3091.824165
# China Container Newbuilding Price Index (CNCPI)...                                        1976.417368

# %%
ship_t1.corrwith(ship_t1.target)
# Out:
# 날짜                                                               -0.522636
# target                                                            1.000000
# Baltic Dry Index (BDI)1985.01.04                                  0.676828
# Baltic Capesize Index (BCI)1999.03.01                             0.544211
# Baltic Panamax Index (BPI)1998.05.06                              0.567728
# Baltic Clean Tanker Index (BCTI)1998.08.03                        0.002284
# Baltic Dirty Tanker Index (BDTI)1998.08.03                       -0.031310
# Baltic Supramax index (BSI)2005.01.01                             0.718575
# Baltic Handysize Index (BHSI)2006.05.23                           0.675930
# SSY/Pacific Capesize Index1997.1.6=4114                           0.769670
# SSY/Atlantic Capesize Index1997.1.6=5000                          0.609087
# Howe Robinson Container Index1997.1.15=1000                      -0.162620
# China Containerized Freight Index (CCFI)1998.1.1=1000             0.683665
# Shanghai Containerized Freight Index (SCFI)2009.10.16=1000        0.696305
# China Coastal Bulk Freight Index (CBFI)2000.1.1=1000              0.439417
# China Newbuilding Price Index (CNPI)2011.07.01=1000               0.394541
# China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000       0.479296
# China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000       0.189348
# China Container Newbuilding Price Index (CNCPI)2011.07.01=1000    0.119158
# dtype: float64

# %%
# ship_t1 으로 무슨 boxplot을 그리려는지 ?

def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
g = sns.FacetGrid(ship_t1, col="target",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e00108ecd98e> in <module>()
#       3     x=plt.xticks(rotation=90)
#       4 g = sns.FacetGrid(ship_t1.iloc[:,1:3], col="target",  col_wrap=20, sharex=False, sharey=False, size=5)
# ----> 5 g = g.map(boxplot)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     741
#     742             # Draw the plot
# --> 743             self._facet_plot(func, ax, plot_args, kwargs)
#     744
#     745         # Finalize the annotations and layout
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     825
#     826         # Draw the plot
# --> 827         func(*plot_args, **plot_kwargs)
#     828
#     829         # Sort out the supporting information
#
# TypeError: boxplot() missing 2 required positional arguments: 'x' and 'y'

# %%
ship_t1.corr()
correlations = ship_t1.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,18,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(ship_t1.columns)
ax.set_yticklabels(ship_t1.columns)
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity

tmp_target = ship_t1['target'].values.reshape(1,-1)
tmp_bdi = ship_t1['Baltic Dry Index (BDI)1985.01.04'].values.reshape(1,-1)
cosine_similarity(tmp_target,tmp_bdi)
# Out:
# array([[0.96140105]])

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 철광석 추이를 쫌 봐야겠다

# %%
ship_index=price_ship[['날짜','Baltic Dry Index (BDI)1985.01.04',
       'Baltic Capesize Index (BCI)1999.03.01',
       'Baltic Panamax Index (BPI)1998.05.06',
       'Baltic Clean Tanker Index (BCTI)1998.08.03',
       'Baltic Dirty Tanker Index (BDTI)1998.08.03',
       'Baltic Supramax index (BSI)2005.01.01',
       'Baltic Handysize Index (BHSI)2006.05.23',
       'SSY/Pacific Capesize Index1997.1.6=4114',
       'SSY/Atlantic Capesize Index1997.1.6=5000',
       'Howe Robinson Container Index1997.1.15=1000',
       'China Containerized Freight Index (CCFI)1998.1.1=1000',
       'Shanghai Containerized Freight Index (SCFI)2009.10.16=1000',
       'China Coastal Bulk Freight Index (CBFI)2000.1.1=1000',
       'China Newbuilding Price Index (CNPI)2011.07.01=1000',
       'China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000',
       'China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000',
       'China Container Newbuilding Price Index (CNCPI)2011.07.01=1000']]

# %%
price_ship.describe()
# Out:
#                  날짜       target  Baltic Dry Index (BDI)1985.01.04  \
# count  1.320000e+03  1320.000000                       1320.000000
# mean   2.015561e+07    76.918142                       1009.057576
# std    1.490460e+04    26.689976                        390.200020
# min    2.013070e+07    38.300000                        290.000000
# 25%    2.014093e+07    57.910000                        720.000000
# 50%    2.015123e+07    67.670000                        966.000000
# 75%    2.017033e+07    87.722500                       1215.000000
# max    2.018070e+07   144.180000                       2337.000000
#
#        Baltic Capesize Index (BCI)1999.03.01  \
# count                            1320.000000
# mean                             1680.630303
# std                               940.334010
# min                               161.000000
# 25%                               954.000000
# 50%                              1575.000000
# 75%                              2265.750000
# max                              4329.000000
#
#        Baltic Panamax Index (BPI)1998.05.06  \
# count                           1320.000000
# mean                             996.409848
# std                              391.089452
# min                              282.000000
# 25%                              678.000000
# 50%                              940.000000
# 75%                             1290.750000
# max                             2096.000000
#
#        Baltic Clean Tanker Index (BCTI)1998.08.03  \
# count                                 1320.000000
# mean                                   580.531818
# std                                     94.314464
# min                                    346.000000
# 25%                                    522.000000
# 50%                                    564.500000
# 75%                                    628.000000
# max                                    867.000000
#
#        Baltic Dirty Tanker Index (BDTI)1998.08.03  \
# count                                 1320.000000
# mean                                   755.837121
# std                                    123.448767
# min                                    416.000000
# 25%                                    655.000000
# 50%                                    747.000000
# 75%                                    835.500000
# max                                   1344.000000
#
#        Baltic Supramax index (BSI)2005.01.01  \
# count                            1320.000000
# mean                              824.359091
# std                               234.788818
# min                               243.000000
# 25%                               665.000000
# 50%                               849.000000
# 75%                               954.500000
# max                              1562.000000
#
#        Baltic Handysize Index (BHSI)2006.05.23  \
# count                              1320.000000
# mean                                476.965909
# std                                 131.870567
# min                                 183.000000
# 25%                                 377.000000
# 50%                                 475.000000
# 75%                                 581.000000
# max                                 821.000000
#
#        SSY/Pacific Capesize Index1997.1.6=4114  \
# count                              1318.000000
# mean                               4343.710167
# std                                1684.628664
# min                                1594.000000
# 25%                                2941.000000
# 50%                                4076.000000
# 75%                                5379.000000
# max                                9548.000000
#
#        SSY/Atlantic Capesize Index1997.1.6=5000  \
# count                               1318.000000
# mean                                5927.469651
# std                                 2004.249353
# min                                 2419.000000
# 25%                                 4203.750000
# 50%                                 5792.000000
# 75%                                 7238.000000
# max                                11593.000000
#
#        Howe Robinson Container Index1997.1.15=1000  \
# count                                  1316.000000
# mean                                    551.108435
# std                                     109.278459
# min                                     392.000000
# 25%                                     467.000000
# 50%                                     535.050000
# 75%                                     607.600000
# max                                     846.000000
#
#        China Containerized Freight Index (CCFI)1998.1.1=1000  \
# count                                        1319.000000
# mean                                          887.450061
# std                                           153.349325
# min                                           632.360000
# 25%                                           772.270000
# 50%                                           837.740000
# 75%                                          1059.980000
# max                                          1170.590000
#
#        Shanghai Containerized Freight Index (SCFI)2009.10.16=1000  \
# count                                        1319.000000
# mean                                          837.640591
# std                                           197.324589
# min                                           400.430000
# 25%                                           705.190000
# 50%                                           824.180000
# 75%                                          1009.170000
# max                                          1195.360000
#
#        China Coastal Bulk Freight Index (CBFI)2000.1.1=1000  \
# count                                        1265.000000
# mean                                         1005.700941
# std                                           165.859376
# min                                           771.010000
# 25%                                           867.490000
# 50%                                           969.660000
# 75%                                          1140.270000
# max                                          1597.830000
#
#        China Newbuilding Price Index (CNPI)2011.07.01=1000  \
# count                                        1313.000000
# mean                                          851.576542
# std                                            71.419976
# min                                           759.000000
# 25%                                           780.000000
# 50%                                           851.000000
# 75%                                           923.000000
# max                                           960.000000
#
#        China Bulker Newbuilding Price Index (CNDPI)2011.07.01=1000  \
# count                                        1313.000000
# mean                                          851.902513
# std                                            75.899683
# min                                           747.000000
# 25%                                           783.000000
# 50%                                           832.000000
# 75%                                           929.000000
# max                                           981.000000
#
#        China Tanker Newbuilding Price Index (CNTPI)2011.07.01=1000  \
# count                                        1313.000000
# mean                                          917.554455
# std                                            68.772592
# min                                           818.000000
# 25%                                           844.000000
# 50%                                           930.000000
# 75%                                           991.000000
# max                                          1003.000000
#
#        China Container Newbuilding Price Index (CNCPI)2011.07.01=1000
# count                                        1313.000000
# mean                                          850.731912
# std                                            43.670499
# min                                           782.000000
# 25%                                           806.000000
# 50%                                           861.000000
# 75%                                           895.000000
# max                                           906.000000

# %%
import scipy.stats as st
y = price_exchange['target']
plt.figure(1); plt.title('target')
sns.distplot(y, kde=False, fit=st.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)
# Out:
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\user\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(font='NanumGothic')
cols = ['target',
       'USD/KRW (미국 달러 / 한국 원)', 'CNY/KRW (중국 인민폐 / 한국 원)',
       'USD/CNY (미국 달러 / 중국 인민폐)']
sns.pairplot(price_exchange[cols], size = 2.5)
plt.show();

# %%
def spearman(frame, features):
    spr = pd.DataFrame()
    spr['feature'] = features
    spr['spearman'] = [frame[f].corr(frame['SalePrice'], 'spearman') for f in features]
    spr = spr.sort_values('spearman')
    plt.figure(figsize=(6, 0.25*len(features)))
    sns.barplot(data=spr, y='feature', x='spearman', orient='h')
    
features = quantitative + qual_encoded
spearman(train, features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6ac20ce39b1e> in <module>()
#       7     sns.barplot(data=spr, y='feature', x='spearman', orient='h')
#       8
# ----> 9 features = quantitative + qual_encoded
#      10 spearman(train, features)
#
# NameError: name 'quantitative' is not defined

# %%
# NA 값이 너무많으므로 일단 다 제거해보자
price=price.dropna(how='any')
price.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-54fa7a9593ee> in <module>()
#       1 # NA 값이 너무많으므로 일단 다 제거해보자
# ----> 2 price=price.dropna(how='any')
#       3 price.info()
#
# NameError: name 'price' is not defined

# %%
target=price[['날짜','철광석 Fines (Daily) [중국(수입가 CFR)] 현물']]
volume=pd.read_csv('중국철광석생산량.csv',encoding='euc-kr')

# %%
volume=volume[5:]
# Out:
#          품목비교 Historical Data
# 날짜                 중국 철광석 생산량
# 20180401               6746.8
# 20180301               6688.5
# 20180201              12346.4
# 20171201              10922.4
# 20171101              10965.8
# 20171001              12007.4
# 20170901              11912.6
# 20170801              11549.1
# 20170701              11466.4
# 20170601              12469.3
# 20170501              10748.1
# 20170401              10337.2
# 20170301                11361
# 20170201              18415.8
# 20161201              11938.6
# 20161101              11667.9
# 20161001              11928.9
# 20160901              11892.7
# 20160801              11506.9
# 20160701              11574.3
# 20160601              12106.4
# 20160501              10754.1
# 20160401              10256.7
# 20160301               9815.8
# 20160201              16187.5
# 20151201              11967.1
# 20151101              11753.4
# 20151001              12534.8
# 20150901              13156.4
# 20150801              12381.4
# 20150701                12619
# 20150601              12848.1
# 20150501              11766.2
# 20150401              10409.5
# 20150301              10510.1
# 20150201               8330.5
# 20150101                 9223
# 20141201              12614.8
# 20141101                12705
# 20141001              13391.4
# 20140901              13763.2
# 20140801              13679.6
# 20140701              13646.3
# 20140601              13970.6
# 20140501              13057.9
# 20140401              12374.4
# 20140301              12133.8
# 20140201                 8841
# 20140101               9788.3
# 20131201              13233.8
# 20131101              13855.8
# 20131001              13548.4
# 20130901              13784.5
# 20130801              13134.7
# 20130701              12275.1

# %%
target
# Out:
#            날짜  철광석 Fines (Daily) [중국(수입가 CFR)] 현물
# 0    20180626                               66.62
# 1    20180625                               65.49
# 2    20180622                               65.34
# 3    20180621                               64.88
# 4    20180620                               65.49
# 5    20180619                               66.45
# 6    20180618                               68.49
# 7    20180614                               68.49
# 8    20180613                               67.02
# 9    20180612                               67.23
# 10   20180611                               66.75
# 11   20180607                               66.84
# 12   20180606                               66.56
# 13   20180605                               66.34
# 14   20180604                               65.47
# 15   20180601                               66.16
# 16   20180531                               65.32
# 17   20180530                               65.78
# 18   20180528                               63.89
# 19   20180525                               63.94
# 20   20180524                               65.54
# 21   20180523                               64.11
# 22   20180522                               64.41
# 23   20180521                               65.30
# 24   20180517                               67.49
# 25   20180516                               68.03
# 26   20180515                               67.28
# 27   20180514                               68.93
# 28   20180511                               67.42
# 29   20180510                               66.83
# ..        ...                                 ...
# 226  20170719                               70.24
# 227  20170718                               68.84
# 228  20170717                               66.81
# 229  20170714                               65.74
# 230  20170713                               65.91
# 231  20170712                               64.05
# 232  20170711                               65.40
# 233  20170710                               64.05
# 234  20170707                               62.80
# 235  20170706                               61.96
# 236  20170705                               63.28
# 237  20170704                               63.23
# 238  20170703                               64.29
# 239  20170630                               64.95
# 240  20170629                               64.71
# 241  20170628                               62.33
# 242  20170627                               59.70
# 243  20170623                               56.75
# 244  20170622                               56.53
# 245  20170621                               56.82
# 246  20170620                               56.45
# 247  20170619                               56.30
# 248  20170616                               55.75
# 249  20170615                               55.23
# 250  20170614                               54.43
# 251  20170613                               53.36
# 252  20170612                               54.87
# 253  20170609                               55.43
# 254  20170608                               55.36
# 255  20170607                               55.43
#
# [256 rows x 2 columns]

# %%
merge=pd.merge(target,volume,on=['날짜'],how='outer')
merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '날짜'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-c98786438b50> in <module>()
# ----> 1 merge=pd.merge(target,volume,on=['날짜'],how='outer')
#       2 merge
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     563         (self.left_join_keys,
#     564          self.right_join_keys,
# --> 565          self.join_names) = self._get_merge_keys()
#     566
#     567         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     822                     if not is_rkey(rk):
#     823                         if rk is not None:
# --> 824                             right_keys.append(right[rk]._values)
#     825                         else:
#     826                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '날짜'
